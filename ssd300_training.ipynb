# %% [markdown]
# # SSD300 Training Tutorial
#
# This tutorial explains how to train an SSD300 on the Pascal VOC datasets. The preset parameters reproduce the training of the original SSD300 "07+12" model. Training SSD512 works simiarly, so there's no extra tutorial for that. The same goes for training on other datasets.
#
# You can find a summary of a full training here to get an impression of what it should look like:
# [SSD300 "07+12" training summary](https://github.com/pierluigiferrari/ssd_keras/blob/master/training_summaries/ssd300_pascal_07%2B12_training_summary.md)

# %%
from keras.optimizers import Adam, SGD
from keras.callbacks import ModelCheckpoint, LearningRateScheduler, TerminateOnNaN, CSVLogger
from keras import backend as K
from keras.models import load_model
from math import ceil
import numpy as np
from matplotlib import pyplot as plt

from models.keras_ssd300 import ssd_300
from keras_loss_function.keras_ssd_loss import SSDLoss
from keras_layers.keras_layer_AnchorBoxes import AnchorBoxes
from keras_layers.keras_layer_DecodeDetections import DecodeDetections
from keras_layers.keras_layer_DecodeDetectionsFast import DecodeDetectionsFast
from keras_layers.keras_layer_L2Normalization import L2Normalization

from ssd_encoder_decoder.ssd_input_encoder import SSDInputEncoder
from ssd_encoder_decoder.ssd_output_decoder import decode_detections, decode_detections_fast

from data_generator.object_detection_2d_data_generator import DataGenerator
from data_generator.object_detection_2d_geometric_ops import Resize
from data_generator.object_detection_2d_photometric_ops import ConvertTo3Channels
from data_generator.data_augmentation_chain_original_ssd import SSDDataAugmentation
from data_generator.object_detection_2d_misc_utils import apply_inverse_transforms

# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## 0. Preliminary note
#
# All places in the code where you need to make any changes are marked `TODO` and explained accordingly. All code cells that don't contain `TODO` markers just need to be executed.

# %% [markdown]
# ## 1. Set the model configuration parameters
#
# This section sets the configuration parameters for the model definition. The parameters set here are being used both by the `ssd_300()` function that builds the SSD300 model as well as further down by the constructor for the `SSDInputEncoder` object that is needed to run the training. Most of these parameters are needed to define the anchor boxes.
#
# The parameters as set below produce the original SSD300 architecture that was trained on the Pascal VOC datsets, i.e. they are all chosen to correspond exactly to their respective counterparts in the `.prototxt` file that defines the original Caffe implementation. Note that the anchor box scaling factors of the original SSD implementation vary depending on the datasets on which the models were trained. The scaling factors used for the MS COCO datasets are smaller than the scaling factors used for the Pascal VOC datasets. The reason why the list of scaling factors has 7 elements while there are only 6 predictor layers is that the last scaling factor is used for the second aspect-ratio-1 box of the last predictor layer. Refer to the documentation for details.
#
# As mentioned above, the parameters set below are not only needed to build the model, but are also passed to the `SSDInputEncoder` constructor further down, which is responsible for matching and encoding ground truth boxes and anchor boxes during the training. In order to do that, it needs to know the anchor box parameters.

# %%
img_height = 300 # Height of the model input images
img_width = 300 # Width of the model input images
img_channels = 3 # Number of color channels of the model input images
mean_color = [123, 117, 104] # The per-channel mean of the images in the dataset. Do not change this value if you're using any of the pre-trained weights.
swap_channels = [2, 1, 0] # The color channel order in the original SSD is BGR, so we'll have the model reverse the color channel order of the input images.
n_classes = 3 # Number of positive classes, e.g. 20 for Pascal VOC, 80 for MS COCO
scales_pascal = [0.1, 0.2, 0.37, 0.54, 0.71, 0.88, 1.05] # The anchor box scaling factors used in the original SSD300 for the Pascal VOC datasets
scales_coco = [0.07, 0.15, 0.33, 0.51, 0.69, 0.87, 1.05] # The anchor box scaling factors used in the original SSD300 for the MS COCO datasets
scales = scales_coco
aspect_ratios = [[1.0, 2.0, 0.5],
                 [1.0, 2.0, 0.5, 3.0, 1.0/3.0],
                 [1.0, 2.0, 0.5, 3.0, 1.0/3.0],
                 [1.0, 2.0, 0.5, 3.0, 1.0/3.0],
                 [1.0, 2.0, 0.5],
                 [1.0, 2.0, 0.5]] # The anchor box aspect ratios used in the original SSD300; the order matters
two_boxes_for_ar1 = True
steps = [8, 16, 32, 64, 100, 300] # The space between two adjacent anchor box center points for each predictor layer.
offsets = [0.5, 0.5, 0.5, 0.5, 0.5, 0.5] # The offsets of the first anchor box center points from the top and left borders of the image as a fraction of the step size for each predictor layer.
clip_boxes = False # Whether or not to clip the anchor boxes to lie entirely within the image boundaries
variances = [0.1, 0.1, 0.2, 0.2] # The variances by which the encoded target coordinates are divided as in the original implementation
normalize_coords = True

# %% [markdown]
# ## 2. Build or load the model
#
# You will want to execute either of the two code cells in the subsequent two sub-sections, not both.

# %% [markdown]
# ### 2.1 Create a new model and load trained VGG-16 weights into it (or trained SSD weights)
#
# If you want to create a new SSD300 model, this is the relevant section for you. If you want to load a previously saved SSD300 model, skip ahead to section 2.2.
#
# The code cell below does the following things:
# 1. It calls the function `ssd_300()` to build the model.
# 2. It then loads the weights file that is found at `weights_path` into the model. You could load the trained VGG-16 weights or you could load the weights of a trained model. If you want to reproduce the original SSD training, load the pre-trained VGG-16 weights. In any case, you need to set the path to the weights file you want to load on your local machine. Download links to all the trained weights are provided in the [README](https://github.com/pierluigiferrari/ssd_keras/blob/master/README.md) of this repository.
# 3. Finally, it compiles the model for the training. In order to do so, we're defining an optimizer (Adam) and a loss function (SSDLoss) to be passed to the `compile()` method.
#
# Normally, the optimizer of choice would be Adam (commented out below), but since the original implementation uses plain SGD with momentum, we'll do the same in order to reproduce the original training. Adam is generally the superior optimizer, so if your goal is not to have everything exactly as in the original training, feel free to switch to Adam. You might need to adjust the learning rate scheduler below slightly in case you use Adam.
#
# Note that the learning rate that is being set here doesn't matter, because further below we'll pass a learning rate scheduler to the training function, which will overwrite any learning rate set here, i.e. what matters are the learning rates that are defined by the learning rate scheduler.
#
# `SSDLoss` is a custom Keras loss function that implements the multi-task that consists of a log loss for classification and a smooth L1 loss for localization. `neg_pos_ratio` and `alpha` are set as in the paper.

# %%
# 1: Build the Keras model.

K.clear_session() # Clear previous models from memory.

model = ssd_300(image_size=(img_height, img_width, img_channels),
                n_classes=n_classes,
                mode='training',
                l2_regularization=0.0005,
                scales=scales,
                aspect_ratios_per_layer=aspect_ratios,
                two_boxes_for_ar1=two_boxes_for_ar1,
                steps=steps,
                offsets=offsets,
                clip_boxes=clip_boxes,
                variances=variances,
                normalize_coords=normalize_coords,
                subtract_mean=mean_color,
                swap_channels=swap_channels)

# 2: Load some weights into the model.

# TODO: Set the path to the weights you want to load.
weights_path = 'weights/VGG_ILSVRC_16_layers_fc_reduced.h5'

model.load_weights(weights_path, by_name=True)

# 3: Instantiate an optimizer and the SSD loss function and compile the model.
#    If you want to follow the original Caffe implementation, use the preset SGD
#    optimizer, otherwise I'd recommend the commented-out Adam optimizer.

#adam = Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)
sgd = SGD(lr=0.001, momentum=0.9, decay=0.0, nesterov=False)

ssd_loss = SSDLoss(neg_pos_ratio=3, alpha=1.0)

model.compile(optimizer=sgd, loss=ssd_loss.compute_loss)

# %% [markdown]
# ### 2.2 Load a previously created model
#
# If you have previously created and saved a model and would now like to load it, execute the next code cell. The only thing you need to do here is to set the path to the saved model HDF5 file that you would like to load.
#
# The SSD model contains custom objects: Neither the loss function nor the anchor box or L2-normalization layer types are contained in the Keras core library, so we need to provide them to the model loader.
#
# This next code cell assumes that you want to load a model that was created in 'training' mode. If you want to load a model that was created in 'inference' or 'inference_fast' mode, you'll have to add the `DecodeDetections` or `DecodeDetectionsFast` layer type to the `custom_objects` dictionary below.

# %%
# TODO: Set the path to the `.h5` file of the model to be loaded.
model_path = 'ssd300_seaship_epoch-01_loss-6.3318_val_loss-4.6728.h5'

# We need to create an SSDLoss object in order to pass that to the model loader.
ssd_loss = SSDLoss(neg_pos_ratio=3, alpha=1.0)

K.clear_session() # Clear previous models from memory.

model = load_model(model_path, custom_objects={'AnchorBoxes': AnchorBoxes,
                                               'L2Normalization': L2Normalization,
                                               'compute_loss': ssd_loss.compute_loss})

# %% [markdown]
# ## 3. Set up the data generators for the training
#
# The code cells below set up the data generators for the training and validation datasets to train the model. The settings below reproduce the original SSD training on Pascal VOC 2007 `trainval` plus 2012 `trainval` and validation on Pascal VOC 2007 `test`.
#
# The only thing you need to change here are the filepaths to the datasets on your local machine. Note that parsing the labels from the XML annotations files can take a while.
#
# Note that the generator provides two options to speed up the training. By default, it loads the individual images for a batch from disk. This has two disadvantages. First, for compressed image formats like JPG, this is a huge computational waste, because every image needs to be decompressed again and again every time it is being loaded. Second, the images on disk are likely not stored in a contiguous block of memory, which may also slow down the loading process. The first option that `DataGenerator` provides to deal with this is to load the entire dataset into memory, which reduces the access time for any image to a negligible amount, but of course this is only an option if you have enough free memory to hold the whole dataset. As a second option, `DataGenerator` provides the possibility to convert the dataset into a single HDF5 file. This HDF5 file stores the images as uncompressed arrays in a contiguous block of memory, which dramatically speeds up the loading time. It's not as good as having the images in memory, but it's a lot better than the default option of loading them from their compressed JPG state every time they are needed. Of course such an HDF5 dataset may require significantly more disk space than the compressed images (around 9 GB total for Pascal VOC 2007 `trainval` plus 2012 `trainval` and another 2.6 GB for 2007 `test`). You can later load these HDF5 datasets directly in the constructor.
#
# The original SSD implementation uses a batch size of 32 for the training. In case you run into GPU memory issues, reduce the batch size accordingly. You need at least 7 GB of free GPU memory to train an SSD300 with 20 object classes with a batch size of 32.
#
# The `DataGenerator` itself is fairly generic. I doesn't contain any data augmentation or bounding box encoding logic. Instead, you pass a list of image transformations and an encoder for the bounding boxes in the `transformations` and `label_encoder` arguments of the data generator's `generate()` method, and the data generator will then apply those given transformations and the encoding to the data. Everything here is preset already, but if you'd like to learn more about the data generator and its data augmentation capabilities, take a look at the detailed tutorial in [this](https://github.com/pierluigiferrari/data_generator_object_detection_2d) repository.
#
# The data augmentation settings defined further down reproduce the data augmentation pipeline of the original SSD training. The training generator receives an object `ssd_data_augmentation`, which is a transformation object that is itself composed of a whole chain of transformations that replicate the data augmentation procedure used to train the original Caffe implementation. The validation generator receives an object `resize`, which simply resizes the input images.
#
# An `SSDInputEncoder` object, `ssd_input_encoder`, is passed to both the training and validation generators. As explained above, it matches the ground truth labels to the model's anchor boxes and encodes the box coordinates into the format that the model needs.
#
# In order to train the model on a dataset other than Pascal VOC, either choose `DataGenerator`'s appropriate parser method that corresponds to your data format, or, if `DataGenerator` does not provide a suitable parser for your data format, you can write an additional parser and add it. Out of the box, `DataGenerator` can handle datasets that use the Pascal VOC format (use `parse_xml()`), the MS COCO format (use `parse_json()`) and a wide range of CSV formats (use `parse_csv()`).

# %%
# 1: Instantiate two `DataGenerator` objects: One for training, one for validation.

# Optional: If you have enough memory, consider loading the images into memory for the reasons explained above.

train_dataset = DataGenerator(load_images_into_memory=False, hdf5_dataset_path=None)
val_dataset = DataGenerator(load_images_into_memory=False, hdf5_dataset_path=None)

# 2: Parse the image and label lists for the training and validation datasets. This can take a while.

# TODO: Set the paths to the datasets here.

# The directories that contain the images.
VOC_2007_images_dir      = '/home/jerry/Datasets/sea_ship/patch2.5/train/JPEGImages'
#VOC_2012_images_dir      = '../../datasets/VOCdevkit/VOC2012/JPEGImages/'

# The directories that contain the annotations.
VOC_2007_annotations_dir      = '/home/jerry/Datasets/sea_ship/patch2.5/train/Annotations/'
#VOC_2012_annotations_dir      = '../../datasets/VOCdevkit/VOC2012/Annotations/'

# The paths to the image sets.
VOC_2007_train_image_set_filename    = '/home/jerry/Datasets/sea_ship/patch2.5/train/ImageSets/Main/train.txt'
#VOC_2012_train_image_set_filename    = '../../datasets/VOCdevkit/VOC2012/ImageSets/Main/train.txt'
VOC_2007_val_image_set_filename      = '/home/jerry/Datasets/sea_ship/patch2.5/train/ImageSets/Main/val.txt'
#VOC_2012_val_image_set_filename      = '../../datasets/VOCdevkit/VOC2012/ImageSets/Main/val.txt'
VOC_2007_trainval_image_set_filename = '/home/jerry/Datasets/sea_ship/patch2.5/train/ImageSets/Main/train.txt'
#VOC_2012_trainval_image_set_filename = '../../datasets/VOCdevkit/VOC2012/ImageSets/Main/trainval.txt'
VOC_2007_test_image_set_filename     = '/home/jerry/Datasets/sea_ship/patch2.5/train/ImageSets/Main/val.txt'

# The XML parser needs to now what object class names to look for and in which order to map them to integers.
classes = ['background',
           'ship', 'carrier', 'warship']

train_dataset.parse_xml(images_dirs=[VOC_2007_images_dir],
                                     #VOC_2012_images_dir],
                        image_set_filenames=[VOC_2007_trainval_image_set_filename],
                                             #VOC_2012_trainval_image_set_filename],
                        annotations_dirs=[VOC_2007_annotations_dir],
                                          #VOC_2012_annotations_dir],
                        classes=classes,
                        include_classes='all',
                        exclude_truncated=False,
                        exclude_difficult=False,
                        ret=False)

val_dataset.parse_xml(images_dirs=[VOC_2007_images_dir],
                      image_set_filenames=[VOC_2007_test_image_set_filename],
                      annotations_dirs=[VOC_2007_annotations_dir],
                      classes=classes,
                      include_classes='all',
                      exclude_truncated=False,
                      exclude_difficult=True,
                      ret=False)

# Optional: Convert the dataset into an HDF5 dataset. This will require more disk space, but will
# speed up the training. Doing this is not relevant in case you activated the `load_images_into_memory`
# option in the constructor, because in that cas the images are in memory already anyway. If you don't
# want to create HDF5 datasets, comment out the subsequent two function calls.

#train_dataset.create_hdf5_dataset(file_path='seaship_train.h5',
#                                  resize=False,
#                                  variable_image_size=True,
#                                  verbose=True)

#val_dataset.create_hdf5_dataset(file_path='seaship_test.h5',
#                                resize=False,
#                                variable_image_size=True,
#                                verbose=True)
# Out:
# Processing image set 'train.txt': 100%|██████████| 8000/8000 [00:06<00:00, 1321.44it/s]
# Processing image set 'val.txt': 100%|██████████| 2000/2000 [00:01<00:00, 1340.09it/s]

# %%
# 3: Set the batch size.

batch_size = 32 # Change the batch size if you like, or if you run into GPU memory issues.

# 4: Set the image transformations for pre-processing and data augmentation options.

# For the training generator:
ssd_data_augmentation = SSDDataAugmentation(img_height=img_height,
                                            img_width=img_width,
                                            background=mean_color)

# For the validation generator:
convert_to_3_channels = ConvertTo3Channels()
resize = Resize(height=img_height, width=img_width)

# 5: Instantiate an encoder that can encode ground truth labels into the format needed by the SSD loss function.

# The encoder constructor needs the spatial dimensions of the model's predictor layers to create the anchor boxes.
predictor_sizes = [model.get_layer('conv4_3_norm_mbox_conf').output_shape[1:3],
                   model.get_layer('fc7_mbox_conf').output_shape[1:3],
                   model.get_layer('conv6_2_mbox_conf').output_shape[1:3],
                   model.get_layer('conv7_2_mbox_conf').output_shape[1:3],
                   model.get_layer('conv8_2_mbox_conf').output_shape[1:3],
                   model.get_layer('conv9_2_mbox_conf').output_shape[1:3]]

ssd_input_encoder = SSDInputEncoder(img_height=img_height,
                                    img_width=img_width,
                                    n_classes=n_classes,
                                    predictor_sizes=predictor_sizes,
                                    scales=scales,
                                    aspect_ratios_per_layer=aspect_ratios,
                                    two_boxes_for_ar1=two_boxes_for_ar1,
                                    steps=steps,
                                    offsets=offsets,
                                    clip_boxes=clip_boxes,
                                    variances=variances,
                                    matching_type='multi',
                                    pos_iou_threshold=0.5,
                                    neg_iou_limit=0.5,
                                    normalize_coords=normalize_coords)

# 6: Create the generator handles that will be passed to Keras' `fit_generator()` function.

train_generator = train_dataset.generate(batch_size=batch_size,
                                         shuffle=True,
                                         transformations=[ssd_data_augmentation],
                                         label_encoder=ssd_input_encoder,
                                         returns={'processed_images',
                                                  'encoded_labels'},
                                         keep_images_without_gt=False)

val_generator = val_dataset.generate(batch_size=batch_size,
                                     shuffle=False,
                                     transformations=[convert_to_3_channels,
                                                      resize],
                                     label_encoder=ssd_input_encoder,
                                     returns={'processed_images',
                                              'encoded_labels'},
                                     keep_images_without_gt=False)

# Get the number of samples in the training and validations datasets.
train_dataset_size = train_dataset.get_dataset_size()
val_dataset_size   = val_dataset.get_dataset_size()

print("Number of images in the training dataset:\t{:>6}".format(train_dataset_size))
print("Number of images in the validation dataset:\t{:>6}".format(val_dataset_size))
# Out:
# Number of images in the training dataset:	  8000
# Number of images in the validation dataset:	  2000

# %% [markdown]
# ## 4. Set the remaining training parameters
#
# We've already chosen an optimizer and set the batch size above, now let's set the remaining training parameters. I'll set one epoch to consist of 1,000 training steps. The next code cell defines a learning rate schedule that replicates the learning rate schedule of the original Caffe implementation for the training of the SSD300 Pascal VOC "07+12" model. That model was trained for 120,000 steps with a learning rate of 0.001 for the first 80,000 steps, 0.0001 for the next 20,000 steps, and 0.00001 for the last 20,000 steps. If you're training on a different dataset, define the learning rate schedule however you see fit.
#
# I'll set only a few essential Keras callbacks below, feel free to add more callbacks if you want TensorBoard summaries or whatever. We obviously need the learning rate scheduler and we want to save the best models during the training. It also makes sense to continuously stream our training history to a CSV log file after every epoch, because if we didn't do that, in case the training terminates with an exception at some point or if the kernel of this Jupyter notebook dies for some reason or anything like that happens, we would lose the entire history for the trained epochs. Finally, we'll also add a callback that makes sure that the training terminates if the loss becomes `NaN`. Depending on the optimizer you use, it can happen that the loss becomes `NaN` during the first iterations of the training. In later iterations it's less of a risk. For example, I've never seen a `NaN` loss when I trained SSD using an Adam optimizer, but I've seen a `NaN` loss a couple of times during the very first couple of hundred training steps of training a new model when I used an SGD optimizer.

# %%
# Define a learning rate schedule.

def lr_schedule(epoch):
    if epoch < 80:
        return 0.0005
    elif epoch < 100:
        return 0.0001
    else:
        return 0.00001

# %%
# Define model callbacks.

# TODO: Set the filepath under which you want to save the model.
model_checkpoint = ModelCheckpoint(filepath='ssd300_seaship_epoch-{epoch:02d}_loss-{loss:.4f}_val_loss-{val_loss:.4f}.h5',
                                   monitor='val_loss',
                                   verbose=1,
                                   save_best_only=True,
                                   save_weights_only=False,
                                   mode='auto',
                                   period=1)
#model_checkpoint.best = 

csv_logger = CSVLogger(filename='ssd300_seaship_training_log.csv',
                       separator=',',
                       append=True)

learning_rate_scheduler = LearningRateScheduler(schedule=lr_schedule,
                                                verbose=1)

terminate_on_nan = TerminateOnNaN()

callbacks = [model_checkpoint,
             csv_logger,
             learning_rate_scheduler,
             terminate_on_nan]

# %% [markdown]
# ## 5. Train

# %% [markdown]
# In order to reproduce the training of the "07+12" model mentioned above, at 1,000 training steps per epoch you'd have to train for 120 epochs. That is going to take really long though, so you might not want to do all 120 epochs in one go and instead train only for a few epochs at a time. You can find a summary of a full training [here](https://github.com/pierluigiferrari/ssd_keras/blob/master/training_summaries/ssd300_pascal_07%2B12_training_summary.md).
#
# In order to only run a partial training and resume smoothly later on, there are a few things you should note:
# 1. Always load the full model if you can, rather than building a new model and loading previously saved weights into it. Optimizers like SGD or Adam keep running averages of past gradient moments internally. If you always save and load full models when resuming a training, then the state of the optimizer is maintained and the training picks up exactly where it left off. If you build a new model and load weights into it, the optimizer is being initialized from scratch, which, especially in the case of Adam, leads to small but unnecessary setbacks every time you resume the training with previously saved weights.
# 2. In order for the learning rate scheduler callback above to work properly, `fit_generator()` needs to know which epoch we're in, otherwise it will start with epoch 0 every time you resume the training. Set `initial_epoch` to be the next epoch of your training. Note that this parameter is zero-based, i.e. the first epoch is epoch 0. If you had trained for 10 epochs previously and now you'd want to resume the training from there, you'd set `initial_epoch = 10` (since epoch 10 is the eleventh epoch). Furthermore, set `final_epoch` to the last epoch you want to run. To stick with the previous example, if you had trained for 10 epochs previously and now you'd want to train for another 10 epochs, you'd set `initial_epoch = 10` and `final_epoch = 20`.
# 3. In order for the model checkpoint callback above to work correctly after a kernel restart, set `model_checkpoint.best` to the best validation loss from the previous training. If you don't do this and a new `ModelCheckpoint` object is created after a kernel restart, that object obviously won't know what the last best validation loss was, so it will always save the weights of the first epoch of your new training and record that loss as its new best loss. This isn't super-important, I just wanted to mention it.

# %%
# If you're resuming a previous training, set `initial_epoch` and `final_epoch` accordingly.
initial_epoch   = 1
final_epoch     = 120
steps_per_epoch = 250

history = model.fit_generator(generator=train_generator,
                              steps_per_epoch=steps_per_epoch,
                              epochs=final_epoch,
                              callbacks=callbacks,
                              validation_data=val_generator,
                              validation_steps=ceil(val_dataset_size/batch_size),
                              initial_epoch=initial_epoch)
# Out:
# Epoch 2/120
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.0005.
# 250/250 [==============================] - 256s 1s/step - loss: 5.1080 - val_loss: 4.3800
#
# Epoch 00002: val_loss improved from inf to 4.38005, saving model to ssd300_seaship_epoch-02_loss-5.1080_val_loss-4.3800.h5
# Epoch 3/120
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.0005.
# 250/250 [==============================] - 251s 1s/step - loss: 4.9852 - val_loss: 4.2812
#
# Epoch 00003: val_loss improved from 4.38005 to 4.28120, saving model to ssd300_seaship_epoch-03_loss-4.9852_val_loss-4.2812.h5
# Epoch 4/120
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.0005.
# 250/250 [==============================] - 251s 1s/step - loss: 4.8782 - val_loss: 4.2094
#
# Epoch 00004: val_loss improved from 4.28120 to 4.20937, saving model to ssd300_seaship_epoch-04_loss-4.8782_val_loss-4.2094.h5
# Epoch 5/120
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.0005.
# 250/250 [==============================] - 250s 998ms/step - loss: 4.7388 - val_loss: 4.1099
#
# Epoch 00005: val_loss improved from 4.20937 to 4.10987, saving model to ssd300_seaship_epoch-05_loss-4.7388_val_loss-4.1099.h5
# Epoch 6/120
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.0005.
# 250/250 [==============================] - 252s 1s/step - loss: 4.6908 - val_loss: 4.1156
#
# Epoch 00006: val_loss did not improve from 4.10987
# Epoch 7/120
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.0005.
# 250/250 [==============================] - 251s 1s/step - loss: 4.6346 - val_loss: 4.0157
#
# Epoch 00007: val_loss improved from 4.10987 to 4.01565, saving model to ssd300_seaship_epoch-07_loss-4.6346_val_loss-4.0157.h5
# Epoch 8/120
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.0005.
# 250/250 [==============================] - 255s 1s/step - loss: 4.5823 - val_loss: 4.0118
#
# Epoch 00008: val_loss improved from 4.01565 to 4.01183, saving model to ssd300_seaship_epoch-08_loss-4.5823_val_loss-4.0118.h5
# Epoch 9/120
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.0005.
# 250/250 [==============================] - 249s 995ms/step - loss: 4.5272 - val_loss: 3.9333
#
# Epoch 00009: val_loss improved from 4.01183 to 3.93332, saving model to ssd300_seaship_epoch-09_loss-4.5272_val_loss-3.9333.h5
# Epoch 10/120
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.0005.
# 250/250 [==============================] - 253s 1s/step - loss: 4.4880 - val_loss: 3.9349
#
# Epoch 00010: val_loss did not improve from 3.93332
# Epoch 11/120
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.0005.
# 250/250 [==============================] - 251s 1s/step - loss: 4.4141 - val_loss: 3.8374
#
# Epoch 00011: val_loss improved from 3.93332 to 3.83739, saving model to ssd300_seaship_epoch-11_loss-4.4141_val_loss-3.8374.h5
# Epoch 12/120
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.0005.
# 250/250 [==============================] - 251s 1s/step - loss: 4.4053 - val_loss: 3.9273
#
# Epoch 00012: val_loss did not improve from 3.83739
# Epoch 13/120
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.0005.
# 250/250 [==============================] - 251s 1s/step - loss: 4.3619 - val_loss: 3.8601
#
# Epoch 00013: val_loss did not improve from 3.83739
# Epoch 14/120
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.0005.
# 250/250 [==============================] - 251s 1s/step - loss: 4.3260 - val_loss: 3.7705
#
# Epoch 00014: val_loss improved from 3.83739 to 3.77046, saving model to ssd300_seaship_epoch-14_loss-4.3260_val_loss-3.7705.h5
# Epoch 15/120
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.0005.
# 250/250 [==============================] - 251s 1s/step - loss: 4.3211 - val_loss: 3.7584
#
# Epoch 00015: val_loss improved from 3.77046 to 3.75839, saving model to ssd300_seaship_epoch-15_loss-4.3211_val_loss-3.7584.h5
# Epoch 16/120
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.0005.
# 250/250 [==============================] - 251s 1s/step - loss: 4.2656 - val_loss: 3.7398
#
# Epoch 00016: val_loss improved from 3.75839 to 3.73977, saving model to ssd300_seaship_epoch-16_loss-4.2656_val_loss-3.7398.h5
# Epoch 17/120
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.0005.
# 250/250 [==============================] - 251s 1s/step - loss: 4.2482 - val_loss: 3.6877
#
# Epoch 00017: val_loss improved from 3.73977 to 3.68767, saving model to ssd300_seaship_epoch-17_loss-4.2482_val_loss-3.6877.h5
# Epoch 18/120
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.0005.
# 250/250 [==============================] - 249s 996ms/step - loss: 4.2412 - val_loss: 3.7365
#
# Epoch 00018: val_loss did not improve from 3.68767
# Epoch 19/120
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.0005.
# 250/250 [==============================] - 250s 1s/step - loss: 4.2235 - val_loss: 3.7050
#
# Epoch 00019: val_loss did not improve from 3.68767
# Epoch 20/120
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 0.0005.
# 250/250 [==============================] - 251s 1s/step - loss: 4.1657 - val_loss: 3.6677
#
# Epoch 00020: val_loss improved from 3.68767 to 3.66770, saving model to ssd300_seaship_epoch-20_loss-4.1657_val_loss-3.6677.h5
# Epoch 21/120
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 0.0005.
# 250/250 [==============================] - 251s 1s/step - loss: 4.1609 - val_loss: 3.6264
#
# Epoch 00021: val_loss improved from 3.66770 to 3.62638, saving model to ssd300_seaship_epoch-21_loss-4.1609_val_loss-3.6264.h5
# Epoch 22/120
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 0.0005.
# 250/250 [==============================] - 250s 1s/step - loss: 4.1239 - val_loss: 3.6226
#
# Epoch 00022: val_loss improved from 3.62638 to 3.62264, saving model to ssd300_seaship_epoch-22_loss-4.1239_val_loss-3.6226.h5
# Epoch 23/120
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 0.0005.
# 250/250 [==============================] - 251s 1s/step - loss: 4.0964 - val_loss: 3.6806
#
# Epoch 00023: val_loss did not improve from 3.62264
# Epoch 24/120
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 0.0005.
# 250/250 [==============================] - 251s 1s/step - loss: 4.1301 - val_loss: 3.5907
#
# Epoch 00024: val_loss improved from 3.62264 to 3.59075, saving model to ssd300_seaship_epoch-24_loss-4.1301_val_loss-3.5907.h5
# Epoch 25/120
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 0.0005.
# 250/250 [==============================] - 251s 1s/step - loss: 4.0466 - val_loss: 3.6113
#
# Epoch 00025: val_loss did not improve from 3.59075
# Epoch 26/120
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 0.0005.
# 250/250 [==============================] - 251s 1s/step - loss: 4.0776 - val_loss: 3.6234
#
# Epoch 00026: val_loss did not improve from 3.59075
# Epoch 27/120
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 0.0005.
# 250/250 [==============================] - 251s 1s/step - loss: 4.0606 - val_loss: 3.5608
#
# Epoch 00027: val_loss improved from 3.59075 to 3.56079, saving model to ssd300_seaship_epoch-27_loss-4.0606_val_loss-3.5608.h5
# Epoch 28/120
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 0.0005.
# 250/250 [==============================] - 251s 1s/step - loss: 4.0182 - val_loss: 3.6166
#
# Epoch 00028: val_loss did not improve from 3.56079
# Epoch 29/120
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 0.0005.
# 250/250 [==============================] - 251s 1s/step - loss: 4.0357 - val_loss: 3.5747
#
# Epoch 00029: val_loss did not improve from 3.56079
# Epoch 30/120
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 0.0005.
# 250/250 [==============================] - 251s 1s/step - loss: 3.9846 - val_loss: 3.5389
#
# Epoch 00030: val_loss improved from 3.56079 to 3.53893, saving model to ssd300_seaship_epoch-30_loss-3.9846_val_loss-3.5389.h5
# Epoch 31/120
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 0.0005.
# 250/250 [==============================] - 251s 1s/step - loss: 3.9829 - val_loss: 3.5305
#
# Epoch 00031: val_loss improved from 3.53893 to 3.53054, saving model to ssd300_seaship_epoch-31_loss-3.9829_val_loss-3.5305.h5
# Epoch 32/120
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 0.0005.
# 250/250 [==============================] - 251s 1s/step - loss: 3.9514 - val_loss: 3.4978
#
# Epoch 00032: val_loss improved from 3.53054 to 3.49779, saving model to ssd300_seaship_epoch-32_loss-3.9514_val_loss-3.4978.h5
# Epoch 33/120
#
# Epoch 00033: LearningRateScheduler reducing learning rate to 0.0005.
# 250/250 [==============================] - 251s 1s/step - loss: 3.9506 - val_loss: 3.4557
#
# Epoch 00033: val_loss improved from 3.49779 to 3.45572, saving model to ssd300_seaship_epoch-33_loss-3.9506_val_loss-3.4557.h5
# Epoch 34/120
#
# Epoch 00034: LearningRateScheduler reducing learning rate to 0.0005.
# 250/250 [==============================] - 251s 1s/step - loss: 3.9535 - val_loss: 3.4994
#
# Epoch 00034: val_loss did not improve from 3.45572
# Epoch 35/120
#
# Epoch 00035: LearningRateScheduler reducing learning rate to 0.0005.
# 250/250 [==============================] - 251s 1s/step - loss: 3.8913 - val_loss: 3.4857
#
# Epoch 00035: val_loss did not improve from 3.45572
# Epoch 36/120
#
# Epoch 00036: LearningRateScheduler reducing learning rate to 0.0005.
# 250/250 [==============================] - 252s 1s/step - loss: 3.9115 - val_loss: 3.4987
#
# Epoch 00036: val_loss did not improve from 3.45572
# Epoch 37/120
#
# Epoch 00037: LearningRateScheduler reducing learning rate to 0.0005.
# 250/250 [==============================] - 251s 1s/step - loss: 3.9171 - val_loss: 3.4349
#
# Epoch 00037: val_loss improved from 3.45572 to 3.43486, saving model to ssd300_seaship_epoch-37_loss-3.9171_val_loss-3.4349.h5
# Epoch 38/120
#
# Epoch 00038: LearningRateScheduler reducing learning rate to 0.0005.
# 250/250 [==============================] - 251s 1s/step - loss: 3.8866 - val_loss: 3.4294
#
# Epoch 00038: val_loss improved from 3.43486 to 3.42943, saving model to ssd300_seaship_epoch-38_loss-3.8866_val_loss-3.4294.h5
# Epoch 39/120
#
# Epoch 00039: LearningRateScheduler reducing learning rate to 0.0005.
# 250/250 [==============================] - 251s 1s/step - loss: 3.8783 - val_loss: 3.4346
#
# Epoch 00039: val_loss did not improve from 3.42943
# Epoch 40/120
#
# Epoch 00040: LearningRateScheduler reducing learning rate to 0.0005.
# 250/250 [==============================] - 251s 1s/step - loss: 3.8447 - val_loss: 3.4084
#
# Epoch 00040: val_loss improved from 3.42943 to 3.40840, saving model to ssd300_seaship_epoch-40_loss-3.8447_val_loss-3.4084.h5
# Epoch 41/120
#
# Epoch 00041: LearningRateScheduler reducing learning rate to 0.0005.
# 250/250 [==============================] - 250s 1s/step - loss: 3.8404 - val_loss: 3.4136
#
# Epoch 00041: val_loss did not improve from 3.40840
# Epoch 42/120
#
# Epoch 00042: LearningRateScheduler reducing learning rate to 0.0005.
# 250/250 [==============================] - 251s 1s/step - loss: 3.8264 - val_loss: 3.3992
#
# Epoch 00042: val_loss improved from 3.40840 to 3.39917, saving model to ssd300_seaship_epoch-42_loss-3.8264_val_loss-3.3992.h5
# Epoch 43/120
#
# Epoch 00043: LearningRateScheduler reducing learning rate to 0.0005.
# 250/250 [==============================] - 251s 1s/step - loss: 3.8278 - val_loss: 3.3830
#
# Epoch 00043: val_loss improved from 3.39917 to 3.38300, saving model to ssd300_seaship_epoch-43_loss-3.8278_val_loss-3.3830.h5
# Epoch 44/120
#
# Epoch 00044: LearningRateScheduler reducing learning rate to 0.0005.
# 250/250 [==============================] - 251s 1s/step - loss: 3.8072 - val_loss: 3.3511
#
# Epoch 00044: val_loss improved from 3.38300 to 3.35105, saving model to ssd300_seaship_epoch-44_loss-3.8072_val_loss-3.3511.h5
# Epoch 45/120
#
# Epoch 00045: LearningRateScheduler reducing learning rate to 0.0005.
# 250/250 [==============================] - 251s 1s/step - loss: 3.7760 - val_loss: 3.3325
#
# Epoch 00045: val_loss improved from 3.35105 to 3.33247, saving model to ssd300_seaship_epoch-45_loss-3.7760_val_loss-3.3325.h5
# Epoch 46/120
#
# Epoch 00046: LearningRateScheduler reducing learning rate to 0.0005.
# 250/250 [==============================] - 251s 1s/step - loss: 3.7714 - val_loss: 3.3322
#
# Epoch 00046: val_loss improved from 3.33247 to 3.33219, saving model to ssd300_seaship_epoch-46_loss-3.7714_val_loss-3.3322.h5
# Epoch 47/120
#
# Epoch 00047: LearningRateScheduler reducing learning rate to 0.0005.
# 250/250 [==============================] - 251s 1s/step - loss: 3.7591 - val_loss: 3.3401
#
# Epoch 00047: val_loss did not improve from 3.33219
# Epoch 48/120
#
# Epoch 00048: LearningRateScheduler reducing learning rate to 0.0005.
# 250/250 [==============================] - 251s 1s/step - loss: 3.7533 - val_loss: 3.3566
#
# Epoch 00048: val_loss did not improve from 3.33219
# Epoch 49/120
#
# Epoch 00049: LearningRateScheduler reducing learning rate to 0.0005.
# 250/250 [==============================] - 251s 1s/step - loss: 3.7331 - val_loss: 3.2813
#
# Epoch 00049: val_loss improved from 3.33219 to 3.28133, saving model to ssd300_seaship_epoch-49_loss-3.7331_val_loss-3.2813.h5
# Epoch 50/120
#
# Epoch 00050: LearningRateScheduler reducing learning rate to 0.0005.
# 250/250 [==============================] - 251s 1s/step - loss: 3.7519 - val_loss: 3.2827
#
# Epoch 00050: val_loss did not improve from 3.28133
# Epoch 51/120
#
# Epoch 00051: LearningRateScheduler reducing learning rate to 0.0005.
# 250/250 [==============================] - 251s 1s/step - loss: 3.7419 - val_loss: 3.3086
#
# Epoch 00051: val_loss did not improve from 3.28133
# Epoch 52/120
#
# Epoch 00052: LearningRateScheduler reducing learning rate to 0.0005.
# 250/250 [==============================] - 251s 1s/step - loss: 3.7396 - val_loss: 3.2567
#
# Epoch 00052: val_loss improved from 3.28133 to 3.25671, saving model to ssd300_seaship_epoch-52_loss-3.7396_val_loss-3.2567.h5
# Epoch 53/120
#
# Epoch 00053: LearningRateScheduler reducing learning rate to 0.0005.
# 250/250 [==============================] - 251s 1s/step - loss: 3.6786 - val_loss: 3.2576
#
# Epoch 00053: val_loss did not improve from 3.25671
# Epoch 54/120
#
# Epoch 00054: LearningRateScheduler reducing learning rate to 0.0005.
# 250/250 [==============================] - 251s 1s/step - loss: 3.6787 - val_loss: 3.2617
#
# Epoch 00054: val_loss did not improve from 3.25671
# Epoch 55/120
#
# Epoch 00055: LearningRateScheduler reducing learning rate to 0.0005.
# 250/250 [==============================] - 251s 1s/step - loss: 3.6793 - val_loss: 3.2966
#
# Epoch 00055: val_loss did not improve from 3.25671
# Epoch 56/120
#
# Epoch 00056: LearningRateScheduler reducing learning rate to 0.0005.
# 250/250 [==============================] - 251s 1s/step - loss: 3.6689 - val_loss: 3.2224
#
# Epoch 00056: val_loss improved from 3.25671 to 3.22237, saving model to ssd300_seaship_epoch-56_loss-3.6689_val_loss-3.2224.h5
# Epoch 57/120
#
# Epoch 00057: LearningRateScheduler reducing learning rate to 0.0005.
# 250/250 [==============================] - 251s 1s/step - loss: 3.6365 - val_loss: 3.2045
#
# Epoch 00057: val_loss improved from 3.22237 to 3.20449, saving model to ssd300_seaship_epoch-57_loss-3.6365_val_loss-3.2045.h5
# Epoch 58/120
#
# Epoch 00058: LearningRateScheduler reducing learning rate to 0.0005.
# 250/250 [==============================] - 251s 1s/step - loss: 3.6544 - val_loss: 3.2566
#
# Epoch 00058: val_loss did not improve from 3.20449
# Epoch 59/120
#
# Epoch 00059: LearningRateScheduler reducing learning rate to 0.0005.
# 250/250 [==============================] - 248s 993ms/step - loss: 3.6280 - val_loss: 3.2163
#
# Epoch 00059: val_loss did not improve from 3.20449
# Epoch 60/120
#
# Epoch 00060: LearningRateScheduler reducing learning rate to 0.0005.
# 250/250 [==============================] - 251s 1s/step - loss: 3.6343 - val_loss: 3.2344
#
# Epoch 00060: val_loss did not improve from 3.20449
# Epoch 61/120
#
# Epoch 00061: LearningRateScheduler reducing learning rate to 0.0005.
# 250/250 [==============================] - 251s 1s/step - loss: 3.6127 - val_loss: 3.2043
#
# Epoch 00061: val_loss improved from 3.20449 to 3.20431, saving model to ssd300_seaship_epoch-61_loss-3.6127_val_loss-3.2043.h5
# Epoch 62/120
#
# Epoch 00062: LearningRateScheduler reducing learning rate to 0.0005.
# 250/250 [==============================] - 251s 1s/step - loss: 3.5910 - val_loss: 3.1661
#
# Epoch 00062: val_loss improved from 3.20431 to 3.16612, saving model to ssd300_seaship_epoch-62_loss-3.5910_val_loss-3.1661.h5
# Epoch 63/120
#
# Epoch 00063: LearningRateScheduler reducing learning rate to 0.0005.
# 250/250 [==============================] - 251s 1s/step - loss: 3.6191 - val_loss: 3.1932
#
# Epoch 00063: val_loss did not improve from 3.16612
# Epoch 64/120
#
# Epoch 00064: LearningRateScheduler reducing learning rate to 0.0005.
# 250/250 [==============================] - 251s 1s/step - loss: 3.5745 - val_loss: 3.1534
#
# Epoch 00064: val_loss improved from 3.16612 to 3.15344, saving model to ssd300_seaship_epoch-64_loss-3.5745_val_loss-3.1534.h5
# Epoch 65/120
#
# Epoch 00065: LearningRateScheduler reducing learning rate to 0.0005.
# 250/250 [==============================] - 251s 1s/step - loss: 3.5782 - val_loss: 3.1469
#
# Epoch 00065: val_loss improved from 3.15344 to 3.14693, saving model to ssd300_seaship_epoch-65_loss-3.5782_val_loss-3.1469.h5
# Epoch 66/120
#
# Epoch 00066: LearningRateScheduler reducing learning rate to 0.0005.
# 250/250 [==============================] - 251s 1s/step - loss: 3.5615 - val_loss: 3.1509
#
# Epoch 00066: val_loss did not improve from 3.14693
# Epoch 67/120
#
# Epoch 00067: LearningRateScheduler reducing learning rate to 0.0005.
# 250/250 [==============================] - 251s 1s/step - loss: 3.5475 - val_loss: 3.1310
#
# Epoch 00067: val_loss improved from 3.14693 to 3.13097, saving model to ssd300_seaship_epoch-67_loss-3.5475_val_loss-3.1310.h5
# Epoch 68/120
#
# Epoch 00068: LearningRateScheduler reducing learning rate to 0.0005.
# 250/250 [==============================] - 251s 1s/step - loss: 3.5625 - val_loss: 3.1687
#
# Epoch 00068: val_loss did not improve from 3.13097
# Epoch 69/120
#
# Epoch 00069: LearningRateScheduler reducing learning rate to 0.0005.
# 250/250 [==============================] - 251s 1s/step - loss: 3.5153 - val_loss: 3.1317
#
# Epoch 00069: val_loss did not improve from 3.13097
# Epoch 70/120
#
# Epoch 00070: LearningRateScheduler reducing learning rate to 0.0005.
# 250/250 [==============================] - 251s 1s/step - loss: 3.5240 - val_loss: 3.1660
#
# Epoch 00070: val_loss did not improve from 3.13097
# Epoch 71/120
#
# Epoch 00071: LearningRateScheduler reducing learning rate to 0.0005.
# 250/250 [==============================] - 251s 1s/step - loss: 3.5232 - val_loss: 3.1291
#
# Epoch 00071: val_loss improved from 3.13097 to 3.12908, saving model to ssd300_seaship_epoch-71_loss-3.5232_val_loss-3.1291.h5
# Epoch 72/120
#
# Epoch 00072: LearningRateScheduler reducing learning rate to 0.0005.
# 250/250 [==============================] - 251s 1s/step - loss: 3.4981 - val_loss: 3.1313
#
# Epoch 00072: val_loss did not improve from 3.12908
# Epoch 73/120
#
# Epoch 00073: LearningRateScheduler reducing learning rate to 0.0005.
# 250/250 [==============================] - 251s 1s/step - loss: 3.5034 - val_loss: 3.1149
#
# Epoch 00073: val_loss improved from 3.12908 to 3.11493, saving model to ssd300_seaship_epoch-73_loss-3.5034_val_loss-3.1149.h5
# Epoch 74/120
#
# Epoch 00074: LearningRateScheduler reducing learning rate to 0.0005.
# 250/250 [==============================] - 251s 1s/step - loss: 3.5215 - val_loss: 3.0914
#
# Epoch 00074: val_loss improved from 3.11493 to 3.09144, saving model to ssd300_seaship_epoch-74_loss-3.5215_val_loss-3.0914.h5
# Epoch 75/120
#
# Epoch 00075: LearningRateScheduler reducing learning rate to 0.0005.
# 250/250 [==============================] - 251s 1s/step - loss: 3.4845 - val_loss: 3.1254
#
# Epoch 00075: val_loss did not improve from 3.09144
# Epoch 76/120
#
# Epoch 00076: LearningRateScheduler reducing learning rate to 0.0005.
# 250/250 [==============================] - 251s 1s/step - loss: 3.4837 - val_loss: 3.0997
#
# Epoch 00076: val_loss did not improve from 3.09144
# Epoch 77/120
#
# Epoch 00077: LearningRateScheduler reducing learning rate to 0.0005.
# 250/250 [==============================] - 251s 1s/step - loss: 3.4582 - val_loss: 3.0689
#
# Epoch 00077: val_loss improved from 3.09144 to 3.06895, saving model to ssd300_seaship_epoch-77_loss-3.4582_val_loss-3.0689.h5
# Epoch 78/120
#
# Epoch 00078: LearningRateScheduler reducing learning rate to 0.0005.
# 250/250 [==============================] - 251s 1s/step - loss: 3.4522 - val_loss: 3.0792
#
# Epoch 00078: val_loss did not improve from 3.06895
# Epoch 79/120
#
# Epoch 00079: LearningRateScheduler reducing learning rate to 0.0005.
# 250/250 [==============================] - 251s 1s/step - loss: 3.4406 - val_loss: 3.0851
#
# Epoch 00079: val_loss did not improve from 3.06895
# Epoch 80/120
#
# Epoch 00080: LearningRateScheduler reducing learning rate to 0.0005.
# 250/250 [==============================] - 251s 1s/step - loss: 3.4662 - val_loss: 3.0647
#
# Epoch 00080: val_loss improved from 3.06895 to 3.06470, saving model to ssd300_seaship_epoch-80_loss-3.4662_val_loss-3.0647.h5
# Epoch 81/120
#
# Epoch 00081: LearningRateScheduler reducing learning rate to 0.0001.
# 250/250 [==============================] - 251s 1s/step - loss: 3.3560 - val_loss: 2.9638
#
# Epoch 00081: val_loss improved from 3.06470 to 2.96383, saving model to ssd300_seaship_epoch-81_loss-3.3560_val_loss-2.9638.h5
# Epoch 82/120
#
# Epoch 00082: LearningRateScheduler reducing learning rate to 0.0001.
# 250/250 [==============================] - 251s 1s/step - loss: 3.3316 - val_loss: 2.9532
#
# Epoch 00082: val_loss improved from 2.96383 to 2.95324, saving model to ssd300_seaship_epoch-82_loss-3.3316_val_loss-2.9532.h5
# Epoch 83/120
#
# Epoch 00083: LearningRateScheduler reducing learning rate to 0.0001.
# 250/250 [==============================] - 251s 1s/step - loss: 3.3226 - val_loss: 2.9513
#
# Epoch 00083: val_loss improved from 2.95324 to 2.95125, saving model to ssd300_seaship_epoch-83_loss-3.3226_val_loss-2.9513.h5
# Epoch 84/120
#
# Epoch 00084: LearningRateScheduler reducing learning rate to 0.0001.
# 250/250 [==============================] - 251s 1s/step - loss: 3.3170 - val_loss: 2.9547
#
# Epoch 00084: val_loss did not improve from 2.95125
# Epoch 85/120
#
# Epoch 00085: LearningRateScheduler reducing learning rate to 0.0001.
# 250/250 [==============================] - 251s 1s/step - loss: 3.3088 - val_loss: 2.9440
#
# Epoch 00085: val_loss improved from 2.95125 to 2.94405, saving model to ssd300_seaship_epoch-85_loss-3.3088_val_loss-2.9440.h5
# Epoch 86/120
#
# Epoch 00086: LearningRateScheduler reducing learning rate to 0.0001.
# 250/250 [==============================] - 251s 1s/step - loss: 3.3020 - val_loss: 2.9398
#
# Epoch 00086: val_loss improved from 2.94405 to 2.93977, saving model to ssd300_seaship_epoch-86_loss-3.3020_val_loss-2.9398.h5
# Epoch 87/120
#
# Epoch 00087: LearningRateScheduler reducing learning rate to 0.0001.
# 250/250 [==============================] - 251s 1s/step - loss: 3.3162 - val_loss: 2.9421
#
# Epoch 00087: val_loss did not improve from 2.93977
# Epoch 88/120
#
# Epoch 00088: LearningRateScheduler reducing learning rate to 0.0001.
# 250/250 [==============================] - 251s 1s/step - loss: 3.2761 - val_loss: 2.9338
#
# Epoch 00088: val_loss improved from 2.93977 to 2.93383, saving model to ssd300_seaship_epoch-88_loss-3.2761_val_loss-2.9338.h5
# Epoch 89/120
#
# Epoch 00089: LearningRateScheduler reducing learning rate to 0.0001.
# 250/250 [==============================] - 251s 1s/step - loss: 3.3044 - val_loss: 2.9321
#
# Epoch 00089: val_loss improved from 2.93383 to 2.93207, saving model to ssd300_seaship_epoch-89_loss-3.3044_val_loss-2.9321.h5
# Epoch 90/120
#
# Epoch 00090: LearningRateScheduler reducing learning rate to 0.0001.
# 250/250 [==============================] - 251s 1s/step - loss: 3.2901 - val_loss: 2.9349
#
# Epoch 00090: val_loss did not improve from 2.93207
# Epoch 91/120
#
# Epoch 00091: LearningRateScheduler reducing learning rate to 0.0001.
# 250/250 [==============================] - 250s 1s/step - loss: 3.2993 - val_loss: 2.9268
#
# Epoch 00091: val_loss improved from 2.93207 to 2.92683, saving model to ssd300_seaship_epoch-91_loss-3.2993_val_loss-2.9268.h5
# Epoch 92/120
#
# Epoch 00092: LearningRateScheduler reducing learning rate to 0.0001.
# 250/250 [==============================] - 251s 1s/step - loss: 3.2917 - val_loss: 2.9258
#
# Epoch 00092: val_loss improved from 2.92683 to 2.92580, saving model to ssd300_seaship_epoch-92_loss-3.2917_val_loss-2.9258.h5
# Epoch 93/120
#
# Epoch 00093: LearningRateScheduler reducing learning rate to 0.0001.
# 250/250 [==============================] - 251s 1s/step - loss: 3.2827 - val_loss: 2.9196
#
# Epoch 00093: val_loss improved from 2.92580 to 2.91960, saving model to ssd300_seaship_epoch-93_loss-3.2827_val_loss-2.9196.h5
# Epoch 94/120
#
# Epoch 00094: LearningRateScheduler reducing learning rate to 0.0001.
# 250/250 [==============================] - 251s 1s/step - loss: 3.2687 - val_loss: 2.9241
#
# Epoch 00094: val_loss did not improve from 2.91960
# Epoch 95/120
#
# Epoch 00095: LearningRateScheduler reducing learning rate to 0.0001.
# 250/250 [==============================] - 251s 1s/step - loss: 3.3011 - val_loss: 2.9218
#
# Epoch 00095: val_loss did not improve from 2.91960
# Epoch 96/120
#
# Epoch 00096: LearningRateScheduler reducing learning rate to 0.0001.
# 250/250 [==============================] - 251s 1s/step - loss: 3.2766 - val_loss: 2.9194
#
# Epoch 00096: val_loss improved from 2.91960 to 2.91944, saving model to ssd300_seaship_epoch-96_loss-3.2766_val_loss-2.9194.h5
# Epoch 97/120
#
# Epoch 00097: LearningRateScheduler reducing learning rate to 0.0001.
# 250/250 [==============================] - 251s 1s/step - loss: 3.2602 - val_loss: 2.9162
#
# Epoch 00097: val_loss improved from 2.91944 to 2.91615, saving model to ssd300_seaship_epoch-97_loss-3.2602_val_loss-2.9162.h5
# Epoch 98/120
#
# Epoch 00098: LearningRateScheduler reducing learning rate to 0.0001.
# 250/250 [==============================] - 251s 1s/step - loss: 3.2771 - val_loss: 2.9127
#
# Epoch 00098: val_loss improved from 2.91615 to 2.91271, saving model to ssd300_seaship_epoch-98_loss-3.2771_val_loss-2.9127.h5
# Epoch 99/120
#
# Epoch 00099: LearningRateScheduler reducing learning rate to 0.0001.
# 250/250 [==============================] - 251s 1s/step - loss: 3.2856 - val_loss: 2.9157
#
# Epoch 00099: val_loss did not improve from 2.91271
# Epoch 100/120
#
# Epoch 00100: LearningRateScheduler reducing learning rate to 0.0001.
# 250/250 [==============================] - 251s 1s/step - loss: 3.2832 - val_loss: 2.9154
#
# Epoch 00100: val_loss did not improve from 2.91271
# Epoch 101/120
#
# Epoch 00101: LearningRateScheduler reducing learning rate to 1e-05.
# 250/250 [==============================] - 251s 1s/step - loss: 3.2795 - val_loss: 2.9042
#
# Epoch 00101: val_loss improved from 2.91271 to 2.90418, saving model to ssd300_seaship_epoch-101_loss-3.2795_val_loss-2.9042.h5
# Epoch 102/120
#
# Epoch 00102: LearningRateScheduler reducing learning rate to 1e-05.
# 250/250 [==============================] - 251s 1s/step - loss: 3.2647 - val_loss: 2.9004
#
# Epoch 00102: val_loss improved from 2.90418 to 2.90036, saving model to ssd300_seaship_epoch-102_loss-3.2647_val_loss-2.9004.h5
# Epoch 103/120
#
# Epoch 00103: LearningRateScheduler reducing learning rate to 1e-05.
# 250/250 [==============================] - 251s 1s/step - loss: 3.2720 - val_loss: 2.9002
#
# Epoch 00103: val_loss improved from 2.90036 to 2.90015, saving model to ssd300_seaship_epoch-103_loss-3.2720_val_loss-2.9002.h5
# Epoch 104/120
#
# Epoch 00104: LearningRateScheduler reducing learning rate to 1e-05.
# 250/250 [==============================] - 251s 1s/step - loss: 3.2513 - val_loss: 2.9010
#
# Epoch 00104: val_loss did not improve from 2.90015
# Epoch 105/120
#
# Epoch 00105: LearningRateScheduler reducing learning rate to 1e-05.
# 250/250 [==============================] - 251s 1s/step - loss: 3.2503 - val_loss: 2.8980
#
# Epoch 00105: val_loss improved from 2.90015 to 2.89799, saving model to ssd300_seaship_epoch-105_loss-3.2503_val_loss-2.8980.h5
# Epoch 106/120
#
# Epoch 00106: LearningRateScheduler reducing learning rate to 1e-05.
# 250/250 [==============================] - 251s 1s/step - loss: 3.2577 - val_loss: 2.8972
#
# Epoch 00106: val_loss improved from 2.89799 to 2.89719, saving model to ssd300_seaship_epoch-106_loss-3.2577_val_loss-2.8972.h5
# Epoch 107/120
#
# Epoch 00107: LearningRateScheduler reducing learning rate to 1e-05.
# 250/250 [==============================] - 251s 1s/step - loss: 3.2594 - val_loss: 2.8983
#
# Epoch 00107: val_loss did not improve from 2.89719
# Epoch 108/120
#
# Epoch 00108: LearningRateScheduler reducing learning rate to 1e-05.
# 250/250 [==============================] - 251s 1s/step - loss: 3.2501 - val_loss: 2.8954
#
# Epoch 00108: val_loss improved from 2.89719 to 2.89537, saving model to ssd300_seaship_epoch-108_loss-3.2501_val_loss-2.8954.h5
# Epoch 109/120
#
# Epoch 00109: LearningRateScheduler reducing learning rate to 1e-05.
# 250/250 [==============================] - 251s 1s/step - loss: 3.2556 - val_loss: 2.8983
#
# Epoch 00109: val_loss did not improve from 2.89537
# Epoch 110/120
#
# Epoch 00110: LearningRateScheduler reducing learning rate to 1e-05.
# 250/250 [==============================] - 251s 1s/step - loss: 3.2381 - val_loss: 2.8974
#
# Epoch 00110: val_loss did not improve from 2.89537
# Epoch 111/120
#
# Epoch 00111: LearningRateScheduler reducing learning rate to 1e-05.
# 250/250 [==============================] - 251s 1s/step - loss: 3.2557 - val_loss: 2.8961
#
# Epoch 00111: val_loss did not improve from 2.89537
# Epoch 112/120
#
# Epoch 00112: LearningRateScheduler reducing learning rate to 1e-05.
# 250/250 [==============================] - 251s 1s/step - loss: 3.2513 - val_loss: 2.8946
#
# Epoch 00112: val_loss improved from 2.89537 to 2.89456, saving model to ssd300_seaship_epoch-112_loss-3.2513_val_loss-2.8946.h5
# Epoch 113/120
#
# Epoch 00113: LearningRateScheduler reducing learning rate to 1e-05.
# 250/250 [==============================] - 252s 1s/step - loss: 3.2497 - val_loss: 2.8967
#
# Epoch 00113: val_loss did not improve from 2.89456
# Epoch 114/120
#
# Epoch 00114: LearningRateScheduler reducing learning rate to 1e-05.
# 250/250 [==============================] - 250s 1s/step - loss: 3.2456 - val_loss: 2.8956
#
# Epoch 00114: val_loss did not improve from 2.89456
# Epoch 115/120
#
# Epoch 00115: LearningRateScheduler reducing learning rate to 1e-05.
# 250/250 [==============================] - 251s 1s/step - loss: 3.2468 - val_loss: 2.8938
#
# Epoch 00115: val_loss improved from 2.89456 to 2.89379, saving model to ssd300_seaship_epoch-115_loss-3.2468_val_loss-2.8938.h5
# Epoch 116/120
#
# Epoch 00116: LearningRateScheduler reducing learning rate to 1e-05.
# 250/250 [==============================] - 250s 1s/step - loss: 3.2607 - val_loss: 2.8937
#
# Epoch 00116: val_loss improved from 2.89379 to 2.89366, saving model to ssd300_seaship_epoch-116_loss-3.2607_val_loss-2.8937.h5
# Epoch 117/120
#
# Epoch 00117: LearningRateScheduler reducing learning rate to 1e-05.
# 250/250 [==============================] - 251s 1s/step - loss: 3.2486 - val_loss: 2.8941
#
# Epoch 00117: val_loss did not improve from 2.89366
# Epoch 118/120
#
# Epoch 00118: LearningRateScheduler reducing learning rate to 1e-05.
# 250/250 [==============================] - 251s 1s/step - loss: 3.2297 - val_loss: 2.8945
#
# Epoch 00118: val_loss did not improve from 2.89366
# Epoch 119/120
#
# Epoch 00119: LearningRateScheduler reducing learning rate to 1e-05.
# 250/250 [==============================] - 251s 1s/step - loss: 3.2412 - val_loss: 2.8940
#
# Epoch 00119: val_loss did not improve from 2.89366
# Epoch 120/120
#
# Epoch 00120: LearningRateScheduler reducing learning rate to 1e-05.
# 250/250 [==============================] - 251s 1s/step - loss: 3.2416 - val_loss: 2.8932
#
# Epoch 00120: val_loss improved from 2.89366 to 2.89322, saving model to ssd300_seaship_epoch-120_loss-3.2416_val_loss-2.8932.h5

# %% [markdown]
# ## 6. Make predictions
#
# Now let's make some predictions on the validation dataset with the trained model. For convenience we'll use the validation generator that we've already set up above. Feel free to change the batch size.
#
# You can set the `shuffle` option to `False` if you would like to check the model's progress on the same image(s) over the course of the training.

# %%
# 1: Set the generator for the predictions.

predict_generator = val_dataset.generate(batch_size=1,
                                         shuffle=True,
                                         transformations=[convert_to_3_channels,
                                                          resize],
                                         label_encoder=None,
                                         returns={'processed_images',
                                                  'filenames',
                                                  'inverse_transform',
                                                  'original_images',
                                                  'original_labels'},
                                         keep_images_without_gt=False)

# %%
# 2: Generate samples.

batch_images, batch_filenames, batch_inverse_transforms, batch_original_images, batch_original_labels = next(predict_generator)

i = 0 # Which batch item to look at

print("Image:", batch_filenames[i])
print()
print("Ground truth boxes:\n")
print(np.array(batch_original_labels[i]))
# Out:
# Image: /home/jerry/Datasets/sea_ship/patch2.5/train/JPEGImages/L13_caishilv_181009025948_3750_1875_50_70_1.jpg
#
# Ground truth boxes:
#
# [[  3  24 241 118 273]]

# %%
# 3: Make predictions.

y_pred = model.predict(batch_images)

# %% [markdown]
# Now let's decode the raw predictions in `y_pred`.
#
# Had we created the model in 'inference' or 'inference_fast' mode, then the model's final layer would be a `DecodeDetections` layer and `y_pred` would already contain the decoded predictions, but since we created the model in 'training' mode, the model outputs raw predictions that still need to be decoded and filtered. This is what the `decode_detections()` function is for. It does exactly what the `DecodeDetections` layer would do, but using Numpy instead of TensorFlow (i.e. on the CPU instead of the GPU).
#
# `decode_detections()` with default argument values follows the procedure of the original SSD implementation: First, a very low confidence threshold of 0.01 is applied to filter out the majority of the predicted boxes, then greedy non-maximum suppression is performed per class with an intersection-over-union threshold of 0.45, and out of what is left after that, the top 200 highest confidence boxes are returned. Those settings are for precision-recall scoring purposes though. In order to get some usable final predictions, we'll set the confidence threshold much higher, e.g. to 0.5, since we're only interested in the very confident predictions.

# %%
# 4: Decode the raw predictions in `y_pred`.

y_pred_decoded = decode_detections(y_pred,
                                   confidence_thresh=0.5,
                                   iou_threshold=0.4,
                                   top_k=200,
                                   normalize_coords=normalize_coords,
                                   img_height=img_height,
                                   img_width=img_width)

# %% [markdown]
# We made the predictions on the resized images, but we'd like to visualize the outcome on the original input images, so we'll convert the coordinates accordingly. Don't worry about that opaque `apply_inverse_transforms()` function below, in this simple case it just aplies `(* original_image_size / resized_image_size)` to the box coordinates.

# %%
# 5: Convert the predictions for the original image.

y_pred_decoded_inv = apply_inverse_transforms(y_pred_decoded, batch_inverse_transforms)

np.set_printoptions(precision=2, suppress=True, linewidth=90)
print("Predicted boxes:\n")
print('   class   conf xmin   ymin   xmax   ymax')
print(y_pred_decoded_inv[i])
# Out:
# Predicted boxes:
#
#    class   conf xmin   ymin   xmax   ymax
# [[  3.     0.86  23.   237.   116.   269.  ]]

# %% [markdown]
# Finally, let's draw the predicted boxes onto the image. Each predicted box says its confidence next to the category name. The ground truth boxes are also drawn onto the image in green for comparison.

# %%
# 5: Draw the predicted boxes onto the image

# Set the colors for the bounding boxes
colors = plt.cm.hsv(np.linspace(0, 1, n_classes+1)).tolist()
classes = ['background',
           'ship', 'carrier', 'warship']

plt.figure(figsize=(20,12))
plt.imshow(batch_original_images[i])

current_axis = plt.gca()

for box in batch_original_labels[i]:
    xmin = box[1]
    ymin = box[2]
    xmax = box[3]
    ymax = box[4]
    label = '{}'.format(classes[int(box[0])])
    current_axis.add_patch(plt.Rectangle((xmin, ymin), xmax-xmin, ymax-ymin, color='green', fill=False, linewidth=2))  
    current_axis.text(xmin, ymin, label, size='x-large', color='white', bbox={'facecolor':'green', 'alpha':1.0})

for box in y_pred_decoded_inv[i]:
    xmin = box[2]
    ymin = box[3]
    xmax = box[4]
    ymax = box[5]
    color = colors[int(box[0])]
    label = '{}: {:.2f}'.format(classes[int(box[0])], box[1])
    current_axis.add_patch(plt.Rectangle((xmin, ymin), xmax-xmin, ymax-ymin, color=color, fill=False, linewidth=2))  
    current_axis.text(xmin, ymin, label, size='x-large', color='white', bbox={'facecolor':color, 'alpha':1.0})
