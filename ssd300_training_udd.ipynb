# %% [markdown]
# # SSD300 Training Tutorial
#
# This tutorial explains how to train an SSD300 on the Pascal VOC datasets. The preset parameters reproduce the training of the original SSD300 "07+12" model. Training SSD512 works simiarly, so there's no extra tutorial for that. The same goes for training on other datasets.
#
# You can find a summary of a full training here to get an impression of what it should look like:
# [SSD300 "07+12" training summary](https://github.com/pierluigiferrari/ssd_keras/blob/master/training_summaries/ssd300_pascal_07%2B12_training_summary.md)

# %%
from keras.optimizers import Adam, SGD
from keras.callbacks import ModelCheckpoint, LearningRateScheduler, TerminateOnNaN, CSVLogger
from keras import backend as K
from keras.models import load_model
from math import ceil
import numpy as np
from matplotlib import pyplot as plt

from models.keras_ssd300 import ssd_300
from keras_loss_function.keras_ssd_loss import SSDLoss
from keras_layers.keras_layer_AnchorBoxes import AnchorBoxes
from keras_layers.keras_layer_DecodeDetections import DecodeDetections
from keras_layers.keras_layer_DecodeDetectionsFast import DecodeDetectionsFast
from keras_layers.keras_layer_L2Normalization import L2Normalization

from ssd_encoder_decoder.ssd_input_encoder import SSDInputEncoder
from ssd_encoder_decoder.ssd_output_decoder import decode_detections, decode_detections_fast

from data_generator.object_detection_2d_data_generator import DataGenerator
from data_generator.object_detection_2d_geometric_ops import Resize
from data_generator.object_detection_2d_photometric_ops import ConvertTo3Channels
from data_generator.data_augmentation_chain_original_ssd import SSDDataAugmentation
from data_generator.object_detection_2d_misc_utils import apply_inverse_transforms
from data_generator.data_augmentation_chain_constant_input_size import DataAugmentationConstantInputSize

# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## 0. Preliminary note
#
# All places in the code where you need to make any changes are marked `TODO` and explained accordingly. All code cells that don't contain `TODO` markers just need to be executed.

# %% [markdown]
# ## 1. Set the model configuration parameters
#
# This section sets the configuration parameters for the model definition. The parameters set here are being used both by the `ssd_300()` function that builds the SSD300 model as well as further down by the constructor for the `SSDInputEncoder` object that is needed to run the training. Most of these parameters are needed to define the anchor boxes.
#
# The parameters as set below produce the original SSD300 architecture that was trained on the Pascal VOC datsets, i.e. they are all chosen to correspond exactly to their respective counterparts in the `.prototxt` file that defines the original Caffe implementation. Note that the anchor box scaling factors of the original SSD implementation vary depending on the datasets on which the models were trained. The scaling factors used for the MS COCO datasets are smaller than the scaling factors used for the Pascal VOC datasets. The reason why the list of scaling factors has 7 elements while there are only 6 predictor layers is that the last scaling factor is used for the second aspect-ratio-1 box of the last predictor layer. Refer to the documentation for details.
#
# As mentioned above, the parameters set below are not only needed to build the model, but are also passed to the `SSDInputEncoder` constructor further down, which is responsible for matching and encoding ground truth boxes and anchor boxes during the training. In order to do that, it needs to know the anchor box parameters.

# %%
img_height = 300 # Height of the model input images
img_width = 480 # Width of the model input images
img_channels = 3 # Number of color channels of the model input images
mean_color = [123, 117, 104] # The per-channel mean of the images in the dataset. Do not change this value if you're using any of the pre-trained weights.
intensity_mean=127.5
intensity_range=127.5
swap_channels = [2, 1, 0] # The color channel order in the original SSD is BGR, so we'll have the model reverse the color channel order of the input images.
n_classes = 5 # Number of positive classes, e.g. 20 for Pascal VOC, 80 for MS COCO
scales_pascal = [0.1, 0.2, 0.37, 0.54, 0.71, 0.88, 1.05] # The anchor box scaling factors used in the original SSD300 for the Pascal VOC datasets
scales_coco = [0.07, 0.15, 0.33, 0.51, 0.69, 0.87, 1.05] # The anchor box scaling factors used in the original SSD300 for the MS COCO datasets
scales = scales_coco
aspect_ratios = [[1.0, 2.0, 0.5],
                 [1.0, 2.0, 0.5, 3.0, 1.0/3.0],
                 [1.0, 2.0, 0.5, 3.0, 1.0/3.0],
                 [1.0, 2.0, 0.5, 3.0, 1.0/3.0],
                 [1.0, 2.0, 0.5],
                 [1.0, 2.0, 0.5]] # The anchor box aspect ratios used in the original SSD300; the order matters
two_boxes_for_ar1 = True
steps = [8, 16, 32, 64, 100, 300] # The space between two adjacent anchor box center points for each predictor layer.
offsets = [0.5, 0.5, 0.5, 0.5, 0.5, 0.5] # The offsets of the first anchor box center points from the top and left borders of the image as a fraction of the step size for each predictor layer.
clip_boxes = False # Whether or not to clip the anchor boxes to lie entirely within the image boundaries
variances = [1.0, 1.0, 1.0, 1.0] # The variances by which the encoded target coordinates are divided as in the original implementation
normalize_coords = True

# %% [markdown]
# ## 2. Build or load the model
#
# You will want to execute either of the two code cells in the subsequent two sub-sections, not both.

# %% [markdown]
# ### 2.1 Create a new model and load trained VGG-16 weights into it (or trained SSD weights)
#
# If you want to create a new SSD300 model, this is the relevant section for you. If you want to load a previously saved SSD300 model, skip ahead to section 2.2.
#
# The code cell below does the following things:
# 1. It calls the function `ssd_300()` to build the model.
# 2. It then loads the weights file that is found at `weights_path` into the model. You could load the trained VGG-16 weights or you could load the weights of a trained model. If you want to reproduce the original SSD training, load the pre-trained VGG-16 weights. In any case, you need to set the path to the weights file you want to load on your local machine. Download links to all the trained weights are provided in the [README](https://github.com/pierluigiferrari/ssd_keras/blob/master/README.md) of this repository.
# 3. Finally, it compiles the model for the training. In order to do so, we're defining an optimizer (Adam) and a loss function (SSDLoss) to be passed to the `compile()` method.
#
# Normally, the optimizer of choice would be Adam (commented out below), but since the original implementation uses plain SGD with momentum, we'll do the same in order to reproduce the original training. Adam is generally the superior optimizer, so if your goal is not to have everything exactly as in the original training, feel free to switch to Adam. You might need to adjust the learning rate scheduler below slightly in case you use Adam.
#
# Note that the learning rate that is being set here doesn't matter, because further below we'll pass a learning rate scheduler to the training function, which will overwrite any learning rate set here, i.e. what matters are the learning rates that are defined by the learning rate scheduler.
#
# `SSDLoss` is a custom Keras loss function that implements the multi-task that consists of a log loss for classification and a smooth L1 loss for localization. `neg_pos_ratio` and `alpha` are set as in the paper.

# %%
# 1: Build the Keras model.

K.clear_session() # Clear previous models from memory.

model = ssd_300(image_size=(img_height, img_width, img_channels),
                n_classes=n_classes,
                mode='training',
                l2_regularization=0.0005,
                scales=scales,
                aspect_ratios_per_layer=aspect_ratios,
                two_boxes_for_ar1=two_boxes_for_ar1,
                steps=steps,
                offsets=offsets,
                clip_boxes=clip_boxes,
                variances=variances,
                normalize_coords=normalize_coords,
                subtract_mean=intensity_mean,
                divide_by_stddev=intensity_range,
                swap_channels=swap_channels)

# 2: Load some weights into the model.

# TODO: Set the path to the weights you want to load.
weights_path = 'VGG_ILSVRC_16_layers_fc_reduced.h5'

model.load_weights(weights_path, by_name=True)

# 3: Instantiate an optimizer and the SSD loss function and compile the model.
#    If you want to follow the original Caffe implementation, use the preset SGD
#    optimizer, otherwise I'd recommend the commented-out Adam optimizer.

#adam = Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)
sgd = SGD(lr=0.001, momentum=0.9, decay=0.0, nesterov=False)

ssd_loss = SSDLoss(neg_pos_ratio=3, alpha=1.0)

model.compile(optimizer=sgd, loss=ssd_loss.compute_loss)

# %% [markdown]
# ### 2.2 Load a previously created model
#
# If you have previously created and saved a model and would now like to load it, execute the next code cell. The only thing you need to do here is to set the path to the saved model HDF5 file that you would like to load.
#
# The SSD model contains custom objects: Neither the loss function nor the anchor box or L2-normalization layer types are contained in the Keras core library, so we need to provide them to the model loader.
#
# This next code cell assumes that you want to load a model that was created in 'training' mode. If you want to load a model that was created in 'inference' or 'inference_fast' mode, you'll have to add the `DecodeDetections` or `DecodeDetectionsFast` layer type to the `custom_objects` dictionary below.

# %%
# TODO: Set the path to the `.h5` file of the model to be loaded.
model_path = 'path/to/trained/model.h5'

# We need to create an SSDLoss object in order to pass that to the model loader.
ssd_loss = SSDLoss(neg_pos_ratio=3, alpha=1.0)

K.clear_session() # Clear previous models from memory.

model = load_model(model_path, custom_objects={'AnchorBoxes': AnchorBoxes,
                                               'L2Normalization': L2Normalization,
                                               'compute_loss': ssd_loss.compute_loss})
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-4-dedb609fbc3f> in <module>()
#       9 model = load_model(model_path, custom_objects={'AnchorBoxes': AnchorBoxes,
#      10                                                'L2Normalization': L2Normalization,
# ---> 11                                                'compute_loss': ssd_loss.compute_loss})
#
# ~/Softwares/anaconda2/envs/tf35/lib/python3.5/site-packages/keras/engine/saving.py in load_model(filepath, custom_objects, compile)
#     248     opened_new_file = not isinstance(filepath, h5py.File)
#     249     if opened_new_file:
# --> 250         f = h5py.File(filepath, mode='r')
#     251     else:
#     252         f = filepath
#
# ~/Softwares/anaconda2/envs/tf35/lib/python3.5/site-packages/h5py/_hl/files.py in __init__(self, name, mode, driver, libver, userblock_size, swmr, **kwds)
#     310             with phil:
#     311                 fapl = make_fapl(driver, libver, **kwds)
# --> 312                 fid = make_fid(name, mode, userblock_size, fapl, swmr=swmr)
#     313
#     314                 if swmr_support:
#
# ~/Softwares/anaconda2/envs/tf35/lib/python3.5/site-packages/h5py/_hl/files.py in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#     140         if swmr and swmr_support:
#     141             flags |= h5f.ACC_SWMR_READ
# --> 142         fid = h5f.open(name, flags, fapl=fapl)
#     143     elif mode == 'r+':
#     144         fid = h5f.open(name, h5f.ACC_RDWR, fapl=fapl)
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/h5f.pyx in h5py.h5f.open()
#
# OSError: Unable to open file (unable to open file: name = 'path/to/trained/model.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)

# %% [markdown]
# ## 3. Set up the data generators for the training
#
# The code cells below set up the data generators for the training and validation datasets to train the model. The settings below reproduce the original SSD training on Pascal VOC 2007 `trainval` plus 2012 `trainval` and validation on Pascal VOC 2007 `test`.
#
# The only thing you need to change here are the filepaths to the datasets on your local machine. Note that parsing the labels from the XML annotations files can take a while.
#
# Note that the generator provides two options to speed up the training. By default, it loads the individual images for a batch from disk. This has two disadvantages. First, for compressed image formats like JPG, this is a huge computational waste, because every image needs to be decompressed again and again every time it is being loaded. Second, the images on disk are likely not stored in a contiguous block of memory, which may also slow down the loading process. The first option that `DataGenerator` provides to deal with this is to load the entire dataset into memory, which reduces the access time for any image to a negligible amount, but of course this is only an option if you have enough free memory to hold the whole dataset. As a second option, `DataGenerator` provides the possibility to convert the dataset into a single HDF5 file. This HDF5 file stores the images as uncompressed arrays in a contiguous block of memory, which dramatically speeds up the loading time. It's not as good as having the images in memory, but it's a lot better than the default option of loading them from their compressed JPG state every time they are needed. Of course such an HDF5 dataset may require significantly more disk space than the compressed images (around 9 GB total for Pascal VOC 2007 `trainval` plus 2012 `trainval` and another 2.6 GB for 2007 `test`). You can later load these HDF5 datasets directly in the constructor.
#
# The original SSD implementation uses a batch size of 32 for the training. In case you run into GPU memory issues, reduce the batch size accordingly. You need at least 7 GB of free GPU memory to train an SSD300 with 20 object classes with a batch size of 32.
#
# The `DataGenerator` itself is fairly generic. I doesn't contain any data augmentation or bounding box encoding logic. Instead, you pass a list of image transformations and an encoder for the bounding boxes in the `transformations` and `label_encoder` arguments of the data generator's `generate()` method, and the data generator will then apply those given transformations and the encoding to the data. Everything here is preset already, but if you'd like to learn more about the data generator and its data augmentation capabilities, take a look at the detailed tutorial in [this](https://github.com/pierluigiferrari/data_generator_object_detection_2d) repository.
#
# The data augmentation settings defined further down reproduce the data augmentation pipeline of the original SSD training. The training generator receives an object `ssd_data_augmentation`, which is a transformation object that is itself composed of a whole chain of transformations that replicate the data augmentation procedure used to train the original Caffe implementation. The validation generator receives an object `resize`, which simply resizes the input images.
#
# An `SSDInputEncoder` object, `ssd_input_encoder`, is passed to both the training and validation generators. As explained above, it matches the ground truth labels to the model's anchor boxes and encodes the box coordinates into the format that the model needs.
#
# In order to train the model on a dataset other than Pascal VOC, either choose `DataGenerator`'s appropriate parser method that corresponds to your data format, or, if `DataGenerator` does not provide a suitable parser for your data format, you can write an additional parser and add it. Out of the box, `DataGenerator` can handle datasets that use the Pascal VOC format (use `parse_xml()`), the MS COCO format (use `parse_json()`) and a wide range of CSV formats (use `parse_csv()`).

# %%
# 1: Instantiate two `DataGenerator` objects: One for training, one for validation.

# Optional: If you have enough memory, consider loading the images into memory for the reasons explained above.

train_dataset = DataGenerator(load_images_into_memory=False, hdf5_dataset_path='dataset_udacity_traffic_train.h5')
val_dataset = DataGenerator(load_images_into_memory=False, hdf5_dataset_path='dataset_udacity_traffic_val.h5')

# 2: Parse the image and label lists for the training and validation datasets.

# TODO: Set the paths to your dataset here.

# Images
images_dir = '/home/jerry/Datasets/udacity_driving_datasets/JPEGImages'

# Ground truth
train_labels_filename = '/home/jerry/Datasets/udacity_driving_datasets/labels_train.csv'
val_labels_filename   = '/home/jerry/Datasets/udacity_driving_datasets/labels_val.csv'

train_dataset.parse_csv(images_dir=images_dir,
                        labels_filename=train_labels_filename,
                        input_format=['image_name', 'xmin', 'xmax', 'ymin', 'ymax', 'class_id'], # This is the order of the first six columns in the CSV file that contains the labels for your dataset. If your labels are in XML format, maybe the XML parser will be helpful, check the documentation.
                        include_classes='all')

val_dataset.parse_csv(images_dir=images_dir,
                      labels_filename=val_labels_filename,
                      input_format=['image_name', 'xmin', 'xmax', 'ymin', 'ymax', 'class_id'],
                      include_classes='all')

# Optional: Convert the dataset into an HDF5 dataset. This will require more disk space, but will
# speed up the training. Doing this is not relevant in case you activated the `load_images_into_memory`
# option in the constructor, because in that cas the images are in memory already anyway. If you don't
# want to create HDF5 datasets, comment out the subsequent two function calls.

#train_dataset.create_hdf5_dataset(file_path='dataset_udacity_traffic_train.h5',
#                                  resize=False,
#                                  variable_image_size=True,
#                                  verbose=True)

#val_dataset.create_hdf5_dataset(file_path='dataset_udacity_traffic_val.h5',
#                                resize=False,
#                                variable_image_size=True,
#                                verbose=True)

# Get the number of samples in the training and validations datasets.
train_dataset_size = train_dataset.get_dataset_size()
val_dataset_size   = val_dataset.get_dataset_size()

print("Number of images in the training dataset:\t{:>6}".format(train_dataset_size))
print("Number of images in the validation dataset:\t{:>6}".format(val_dataset_size))
# Out:
# Loading labels: 100%|██████████| 18000/18000 [00:02<00:00, 6362.99it/s]
# Loading image IDs: 100%|██████████| 18000/18000 [00:01<00:00, 14510.13it/s]
# Loading labels: 100%|██████████| 4241/4241 [00:00<00:00, 6316.84it/s]
# Loading image IDs: 100%|██████████| 4241/4241 [00:00<00:00, 14532.95it/s]
# Number of images in the training dataset:	 18000
# Number of images in the validation dataset:	  4241

# %%
# 3: Set the batch size.

batch_size = 12 # Change the batch size if you like, or if you run into GPU memory issues.

# 4: Set the image transformations for pre-processing and data augmentation options.

# For the training generator:
data_augmentation_chain = DataAugmentationConstantInputSize(random_brightness=(-48, 48, 0.5),
                                                            random_contrast=(0.5, 1.8, 0.5),
                                                            random_saturation=(0.5, 1.8, 0.5),
                                                            random_hue=(18, 0.5),
                                                            random_flip=0.5,
                                                            random_translate=((0.03,0.5), (0.03,0.5), 0.5),
                                                            random_scale=(0.5, 2.0, 0.5),
                                                            n_trials_max=3,
                                                            clip_boxes=True,
                                                            overlap_criterion='area',
                                                            bounds_box_filter=(0.3, 1.0),
                                                            bounds_validator=(0.5, 1.0),
                                                            n_boxes_min=1,
                                                            background=(0,0,0))

# For the validation generator:
convert_to_3_channels = ConvertTo3Channels()
resize = Resize(height=img_height, width=img_width)

# 5: Instantiate an encoder that can encode ground truth labels into the format needed by the SSD loss function.

# The encoder constructor needs the spatial dimensions of the model's predictor layers to create the anchor boxes.
predictor_sizes = [model.get_layer('conv4_3_norm_mbox_conf').output_shape[1:3],
                   model.get_layer('fc7_mbox_conf').output_shape[1:3],
                   model.get_layer('conv6_2_mbox_conf').output_shape[1:3],
                   model.get_layer('conv7_2_mbox_conf').output_shape[1:3],
                   model.get_layer('conv8_2_mbox_conf').output_shape[1:3],
                   model.get_layer('conv9_2_mbox_conf').output_shape[1:3]]

ssd_input_encoder = SSDInputEncoder(img_height=img_height,
                                    img_width=img_width,
                                    n_classes=n_classes,
                                    predictor_sizes=predictor_sizes,
                                    scales=scales,
                                    aspect_ratios_per_layer=aspect_ratios,
                                    two_boxes_for_ar1=two_boxes_for_ar1,
                                    steps=steps,
                                    offsets=offsets,
                                    clip_boxes=clip_boxes,
                                    variances=variances,
                                    matching_type='multi',
                                    pos_iou_threshold=0.5,
                                    neg_iou_limit=0.5,
                                    normalize_coords=normalize_coords)

# 6: Create the generator handles that will be passed to Keras' `fit_generator()` function.

train_generator = train_dataset.generate(batch_size=batch_size,
                                         shuffle=True,
                                         transformations=[data_augmentation_chain],
                                         label_encoder=ssd_input_encoder,
                                         returns={'processed_images',
                                                  'encoded_labels'},
                                         keep_images_without_gt=False)

val_generator = val_dataset.generate(batch_size=batch_size,
                                     shuffle=False,
                                     transformations=[],
                                     label_encoder=ssd_input_encoder,
                                     returns={'processed_images',
                                              'encoded_labels'},
                                     keep_images_without_gt=False)

# Get the number of samples in the training and validations datasets.
train_dataset_size = train_dataset.get_dataset_size()
val_dataset_size   = val_dataset.get_dataset_size()

print("Number of images in the training dataset:\t{:>6}".format(train_dataset_size))
print("Number of images in the validation dataset:\t{:>6}".format(val_dataset_size))
# Out:
# Number of images in the training dataset:	 18000
# Number of images in the validation dataset:	  4241

# %% [markdown]
# ## 4. Set the remaining training parameters
#
# We've already chosen an optimizer and set the batch size above, now let's set the remaining training parameters. I'll set one epoch to consist of 1,000 training steps. The next code cell defines a learning rate schedule that replicates the learning rate schedule of the original Caffe implementation for the training of the SSD300 Pascal VOC "07+12" model. That model was trained for 120,000 steps with a learning rate of 0.001 for the first 80,000 steps, 0.0001 for the next 20,000 steps, and 0.00001 for the last 20,000 steps. If you're training on a different dataset, define the learning rate schedule however you see fit.
#
# I'll set only a few essential Keras callbacks below, feel free to add more callbacks if you want TensorBoard summaries or whatever. We obviously need the learning rate scheduler and we want to save the best models during the training. It also makes sense to continuously stream our training history to a CSV log file after every epoch, because if we didn't do that, in case the training terminates with an exception at some point or if the kernel of this Jupyter notebook dies for some reason or anything like that happens, we would lose the entire history for the trained epochs. Finally, we'll also add a callback that makes sure that the training terminates if the loss becomes `NaN`. Depending on the optimizer you use, it can happen that the loss becomes `NaN` during the first iterations of the training. In later iterations it's less of a risk. For example, I've never seen a `NaN` loss when I trained SSD using an Adam optimizer, but I've seen a `NaN` loss a couple of times during the very first couple of hundred training steps of training a new model when I used an SGD optimizer.

# %%
# Define a learning rate schedule.

def lr_schedule(epoch):
    if epoch < 80:
        return 0.0003
    elif epoch < 100:
        return 0.0001
    else:
        return 0.00001

# %%
# Define model callbacks.

# TODO: Set the filepath under which you want to save the model.
model_checkpoint = ModelCheckpoint(filepath='ssd300_udd_epoch-{epoch:02d}_loss-{loss:.4f}_val_loss-{val_loss:.4f}.h5',
                                   monitor='val_loss',
                                   verbose=1,
                                   save_best_only=True,
                                   save_weights_only=False,
                                   mode='auto',
                                   period=1)
#model_checkpoint.best = 

csv_logger = CSVLogger(filename='ssd300_udd_training_log.csv',
                       separator=',',
                       append=True)

learning_rate_scheduler = LearningRateScheduler(schedule=lr_schedule,
                                                verbose=1)

terminate_on_nan = TerminateOnNaN()

callbacks = [model_checkpoint,
             csv_logger,
             learning_rate_scheduler,
             terminate_on_nan]

# %% [markdown]
# ## 5. Train

# %% [markdown]
# In order to reproduce the training of the "07+12" model mentioned above, at 1,000 training steps per epoch you'd have to train for 120 epochs. That is going to take really long though, so you might not want to do all 120 epochs in one go and instead train only for a few epochs at a time. You can find a summary of a full training [here](https://github.com/pierluigiferrari/ssd_keras/blob/master/training_summaries/ssd300_pascal_07%2B12_training_summary.md).
#
# In order to only run a partial training and resume smoothly later on, there are a few things you should note:
# 1. Always load the full model if you can, rather than building a new model and loading previously saved weights into it. Optimizers like SGD or Adam keep running averages of past gradient moments internally. If you always save and load full models when resuming a training, then the state of the optimizer is maintained and the training picks up exactly where it left off. If you build a new model and load weights into it, the optimizer is being initialized from scratch, which, especially in the case of Adam, leads to small but unnecessary setbacks every time you resume the training with previously saved weights.
# 2. In order for the learning rate scheduler callback above to work properly, `fit_generator()` needs to know which epoch we're in, otherwise it will start with epoch 0 every time you resume the training. Set `initial_epoch` to be the next epoch of your training. Note that this parameter is zero-based, i.e. the first epoch is epoch 0. If you had trained for 10 epochs previously and now you'd want to resume the training from there, you'd set `initial_epoch = 10` (since epoch 10 is the eleventh epoch). Furthermore, set `final_epoch` to the last epoch you want to run. To stick with the previous example, if you had trained for 10 epochs previously and now you'd want to train for another 10 epochs, you'd set `initial_epoch = 10` and `final_epoch = 20`.
# 3. In order for the model checkpoint callback above to work correctly after a kernel restart, set `model_checkpoint.best` to the best validation loss from the previous training. If you don't do this and a new `ModelCheckpoint` object is created after a kernel restart, that object obviously won't know what the last best validation loss was, so it will always save the weights of the first epoch of your new training and record that loss as its new best loss. This isn't super-important, I just wanted to mention it.

# %%
# If you're resuming a previous training, set `initial_epoch` and `final_epoch` accordingly.
initial_epoch   = 0
final_epoch     = 120
steps_per_epoch = 1000

history = model.fit_generator(generator=train_generator,
                              steps_per_epoch=steps_per_epoch,
                              epochs=final_epoch,
                              callbacks=callbacks,
                              validation_data=val_generator,
                              validation_steps=ceil(val_dataset_size/batch_size),
                              initial_epoch=initial_epoch)
# Out:
# Epoch 1/120
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0003.
# 1000/1000 [==============================] - 665s 665ms/step - loss: 7.1854 - val_loss: 6.0343
#
# Epoch 00001: val_loss improved from inf to 6.03426, saving model to ssd300_udd_epoch-01_loss-7.1854_val_loss-6.0343.h5
# Epoch 2/120
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.0003.
# 1000/1000 [==============================] - 670s 670ms/step - loss: 5.9168 - val_loss: 5.7806
#
# Epoch 00002: val_loss improved from 6.03426 to 5.78061, saving model to ssd300_udd_epoch-02_loss-5.9168_val_loss-5.7806.h5
# Epoch 3/120
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.0003.
# 1000/1000 [==============================] - 666s 666ms/step - loss: 5.7492 - val_loss: 5.7373
#
# Epoch 00003: val_loss improved from 5.78061 to 5.73727, saving model to ssd300_udd_epoch-03_loss-5.7492_val_loss-5.7373.h5
# Epoch 4/120
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.0003.
# 1000/1000 [==============================] - 664s 664ms/step - loss: 5.6682 - val_loss: 5.6320
#
# Epoch 00004: val_loss improved from 5.73727 to 5.63201, saving model to ssd300_udd_epoch-04_loss-5.6682_val_loss-5.6320.h5
# Epoch 5/120
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.0003.
# 1000/1000 [==============================] - 663s 663ms/step - loss: 5.5756 - val_loss: 5.5503
#
# Epoch 00005: val_loss improved from 5.63201 to 5.55034, saving model to ssd300_udd_epoch-05_loss-5.5756_val_loss-5.5503.h5
# Epoch 6/120
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.0003.
# 1000/1000 [==============================] - 662s 662ms/step - loss: 5.5309 - val_loss: 5.5155
#
# Epoch 00006: val_loss improved from 5.55034 to 5.51549, saving model to ssd300_udd_epoch-06_loss-5.5309_val_loss-5.5155.h5
# Epoch 7/120
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.0003.
# 1000/1000 [==============================] - 668s 668ms/step - loss: 5.4723 - val_loss: 5.4372
#
# Epoch 00007: val_loss improved from 5.51549 to 5.43715, saving model to ssd300_udd_epoch-07_loss-5.4723_val_loss-5.4372.h5
# Epoch 8/120
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.0003.
# 1000/1000 [==============================] - 672s 672ms/step - loss: 5.4143 - val_loss: 5.4243
#
# Epoch 00008: val_loss improved from 5.43715 to 5.42426, saving model to ssd300_udd_epoch-08_loss-5.4143_val_loss-5.4243.h5
# Epoch 9/120
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.0003.
# 1000/1000 [==============================] - 671s 671ms/step - loss: 5.3597 - val_loss: 5.3596
#
# Epoch 00009: val_loss improved from 5.42426 to 5.35964, saving model to ssd300_udd_epoch-09_loss-5.3597_val_loss-5.3596.h5
# Epoch 10/120
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.0003.
# 1000/1000 [==============================] - 673s 673ms/step - loss: 5.3090 - val_loss: 5.3196
#
# Epoch 00010: val_loss improved from 5.35964 to 5.31964, saving model to ssd300_udd_epoch-10_loss-5.3090_val_loss-5.3196.h5
# Epoch 11/120
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.0003.
# 1000/1000 [==============================] - 670s 670ms/step - loss: 5.2575 - val_loss: 5.2981
#
# Epoch 00011: val_loss improved from 5.31964 to 5.29813, saving model to ssd300_udd_epoch-11_loss-5.2575_val_loss-5.2981.h5
# Epoch 12/120
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.0003.
# 1000/1000 [==============================] - 671s 671ms/step - loss: 5.1944 - val_loss: 5.2136
#
# Epoch 00012: val_loss improved from 5.29813 to 5.21360, saving model to ssd300_udd_epoch-12_loss-5.1944_val_loss-5.2136.h5
# Epoch 13/120
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.0003.
# 1000/1000 [==============================] - 670s 670ms/step - loss: 5.1484 - val_loss: 5.1946
#
# Epoch 00013: val_loss improved from 5.21360 to 5.19463, saving model to ssd300_udd_epoch-13_loss-5.1484_val_loss-5.1946.h5
# Epoch 14/120
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.0003.
# 1000/1000 [==============================] - 670s 670ms/step - loss: 5.1035 - val_loss: 5.1664
#
# Epoch 00014: val_loss improved from 5.19463 to 5.16640, saving model to ssd300_udd_epoch-14_loss-5.1035_val_loss-5.1664.h5
# Epoch 15/120
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.0003.
# 1000/1000 [==============================] - 671s 671ms/step - loss: 5.0611 - val_loss: 5.1258
#
# Epoch 00015: val_loss improved from 5.16640 to 5.12580, saving model to ssd300_udd_epoch-15_loss-5.0611_val_loss-5.1258.h5
# Epoch 16/120
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.0003.
# 1000/1000 [==============================] - 671s 671ms/step - loss: 5.0236 - val_loss: 5.0630
#
# Epoch 00016: val_loss improved from 5.12580 to 5.06297, saving model to ssd300_udd_epoch-16_loss-5.0236_val_loss-5.0630.h5
# Epoch 17/120
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.0003.
# 1000/1000 [==============================] - 670s 670ms/step - loss: 4.9836 - val_loss: 5.0416
#
# Epoch 00017: val_loss improved from 5.06297 to 5.04163, saving model to ssd300_udd_epoch-17_loss-4.9836_val_loss-5.0416.h5
# Epoch 18/120
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.0003.
# 1000/1000 [==============================] - 671s 671ms/step - loss: 4.9537 - val_loss: 5.0161
#
# Epoch 00018: val_loss improved from 5.04163 to 5.01609, saving model to ssd300_udd_epoch-18_loss-4.9537_val_loss-5.0161.h5
# Epoch 19/120
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.0003.
# 1000/1000 [==============================] - 671s 671ms/step - loss: 4.9194 - val_loss: 5.0454
#
# Epoch 00019: val_loss did not improve from 5.01609
# Epoch 20/120
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 0.0003.
# 1000/1000 [==============================] - 673s 673ms/step - loss: 4.8812 - val_loss: 4.9859
#
# Epoch 00020: val_loss improved from 5.01609 to 4.98588, saving model to ssd300_udd_epoch-20_loss-4.8812_val_loss-4.9859.h5
# Epoch 21/120
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 0.0003.
# 1000/1000 [==============================] - 672s 672ms/step - loss: 4.8657 - val_loss: 4.9239
#
# Epoch 00021: val_loss improved from 4.98588 to 4.92393, saving model to ssd300_udd_epoch-21_loss-4.8657_val_loss-4.9239.h5
# Epoch 22/120
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 0.0003.
# 1000/1000 [==============================] - 671s 671ms/step - loss: 4.8308 - val_loss: 4.9362
#
# Epoch 00022: val_loss did not improve from 4.92393
# Epoch 23/120
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 0.0003.
# 1000/1000 [==============================] - 680s 680ms/step - loss: 4.7926 - val_loss: 4.9004
#
# Epoch 00023: val_loss improved from 4.92393 to 4.90040, saving model to ssd300_udd_epoch-23_loss-4.7926_val_loss-4.9004.h5
# Epoch 24/120
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 0.0003.
# 1000/1000 [==============================] - 671s 671ms/step - loss: 4.7678 - val_loss: 4.8760
#
# Epoch 00024: val_loss improved from 4.90040 to 4.87603, saving model to ssd300_udd_epoch-24_loss-4.7678_val_loss-4.8760.h5
# Epoch 25/120
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 0.0003.
# 1000/1000 [==============================] - 670s 670ms/step - loss: 4.7440 - val_loss: 4.8380
#
# Epoch 00025: val_loss improved from 4.87603 to 4.83800, saving model to ssd300_udd_epoch-25_loss-4.7440_val_loss-4.8380.h5
# Epoch 26/120
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 0.0003.
# 1000/1000 [==============================] - 671s 671ms/step - loss: 4.7230 - val_loss: 4.8627
#
# Epoch 00026: val_loss did not improve from 4.83800
# Epoch 27/120
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 0.0003.
# 1000/1000 [==============================] - 671s 671ms/step - loss: 4.6847 - val_loss: 4.8390
#
# Epoch 00027: val_loss did not improve from 4.83800
# Epoch 28/120
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 0.0003.
# 1000/1000 [==============================] - 670s 670ms/step - loss: 4.6712 - val_loss: 4.7727
#
# Epoch 00028: val_loss improved from 4.83800 to 4.77273, saving model to ssd300_udd_epoch-28_loss-4.6712_val_loss-4.7727.h5
# Epoch 29/120
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 0.0003.
# 1000/1000 [==============================] - 673s 673ms/step - loss: 4.6310 - val_loss: 4.7876
#
# Epoch 00029: val_loss did not improve from 4.77273
# Epoch 30/120
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 0.0003.
# 1000/1000 [==============================] - 667s 667ms/step - loss: 4.6192 - val_loss: 4.7464
#
# Epoch 00030: val_loss improved from 4.77273 to 4.74641, saving model to ssd300_udd_epoch-30_loss-4.6192_val_loss-4.7464.h5
# Epoch 31/120
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 0.0003.
# 1000/1000 [==============================] - 667s 667ms/step - loss: 4.5928 - val_loss: 4.7324
#
# Epoch 00031: val_loss improved from 4.74641 to 4.73243, saving model to ssd300_udd_epoch-31_loss-4.5928_val_loss-4.7324.h5
# Epoch 32/120
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 0.0003.
# 1000/1000 [==============================] - 665s 665ms/step - loss: 4.5791 - val_loss: 4.7204
#
# Epoch 00032: val_loss improved from 4.73243 to 4.72042, saving model to ssd300_udd_epoch-32_loss-4.5791_val_loss-4.7204.h5
# Epoch 33/120
#
# Epoch 00033: LearningRateScheduler reducing learning rate to 0.0003.
# 1000/1000 [==============================] - 666s 666ms/step - loss: 4.5448 - val_loss: 4.7136
#
# Epoch 00033: val_loss improved from 4.72042 to 4.71357, saving model to ssd300_udd_epoch-33_loss-4.5448_val_loss-4.7136.h5
# Epoch 34/120
#
# Epoch 00034: LearningRateScheduler reducing learning rate to 0.0003.
# 1000/1000 [==============================] - 664s 664ms/step - loss: 4.5285 - val_loss: 4.6878
#
# Epoch 00034: val_loss improved from 4.71357 to 4.68776, saving model to ssd300_udd_epoch-34_loss-4.5285_val_loss-4.6878.h5
# Epoch 35/120
#
# Epoch 00035: LearningRateScheduler reducing learning rate to 0.0003.
# 1000/1000 [==============================] - 665s 665ms/step - loss: 4.4987 - val_loss: 4.6704
#
# Epoch 00035: val_loss improved from 4.68776 to 4.67039, saving model to ssd300_udd_epoch-35_loss-4.4987_val_loss-4.6704.h5
# Epoch 36/120
#
# Epoch 00036: LearningRateScheduler reducing learning rate to 0.0003.
# 1000/1000 [==============================] - 665s 665ms/step - loss: 4.4817 - val_loss: 4.6380
#
# Epoch 00036: val_loss improved from 4.67039 to 4.63796, saving model to ssd300_udd_epoch-36_loss-4.4817_val_loss-4.6380.h5
# Epoch 37/120
#
# Epoch 00037: LearningRateScheduler reducing learning rate to 0.0003.
# 1000/1000 [==============================] - 665s 665ms/step - loss: 4.4556 - val_loss: 4.6394
#
# Epoch 00037: val_loss did not improve from 4.63796
# Epoch 38/120
#
# Epoch 00038: LearningRateScheduler reducing learning rate to 0.0003.
# 1000/1000 [==============================] - 665s 665ms/step - loss: 4.4341 - val_loss: 4.6199
#
# Epoch 00038: val_loss improved from 4.63796 to 4.61994, saving model to ssd300_udd_epoch-38_loss-4.4341_val_loss-4.6199.h5
# Epoch 39/120
#
# Epoch 00039: LearningRateScheduler reducing learning rate to 0.0003.
# 1000/1000 [==============================] - 665s 665ms/step - loss: 4.4143 - val_loss: 4.5912
#
# Epoch 00039: val_loss improved from 4.61994 to 4.59119, saving model to ssd300_udd_epoch-39_loss-4.4143_val_loss-4.5912.h5
# Epoch 40/120
#
# Epoch 00040: LearningRateScheduler reducing learning rate to 0.0003.
# 1000/1000 [==============================] - 665s 665ms/step - loss: 4.3931 - val_loss: 4.5765
#
# Epoch 00040: val_loss improved from 4.59119 to 4.57647, saving model to ssd300_udd_epoch-40_loss-4.3931_val_loss-4.5765.h5
# Epoch 41/120
#
# Epoch 00041: LearningRateScheduler reducing learning rate to 0.0003.
# 1000/1000 [==============================] - 665s 665ms/step - loss: 4.3755 - val_loss: 4.5626
#
# Epoch 00041: val_loss improved from 4.57647 to 4.56264, saving model to ssd300_udd_epoch-41_loss-4.3755_val_loss-4.5626.h5
# Epoch 42/120
#
# Epoch 00042: LearningRateScheduler reducing learning rate to 0.0003.
# 1000/1000 [==============================] - 665s 665ms/step - loss: 4.3631 - val_loss: 4.5380
#
# Epoch 00042: val_loss improved from 4.56264 to 4.53803, saving model to ssd300_udd_epoch-42_loss-4.3631_val_loss-4.5380.h5
# Epoch 43/120
#
# Epoch 00043: LearningRateScheduler reducing learning rate to 0.0003.
# 1000/1000 [==============================] - 665s 665ms/step - loss: 4.3302 - val_loss: 4.5435
#
# Epoch 00043: val_loss did not improve from 4.53803
# Epoch 44/120
#
# Epoch 00044: LearningRateScheduler reducing learning rate to 0.0003.
# 1000/1000 [==============================] - 665s 665ms/step - loss: 4.3219 - val_loss: 4.5427
#
# Epoch 00044: val_loss did not improve from 4.53803
# Epoch 45/120
#
# Epoch 00045: LearningRateScheduler reducing learning rate to 0.0003.
# 1000/1000 [==============================] - 665s 665ms/step - loss: 4.2991 - val_loss: 4.5251
#
# Epoch 00045: val_loss improved from 4.53803 to 4.52513, saving model to ssd300_udd_epoch-45_loss-4.2991_val_loss-4.5251.h5
# Epoch 46/120
#
# Epoch 00046: LearningRateScheduler reducing learning rate to 0.0003.
# 1000/1000 [==============================] - 666s 666ms/step - loss: 4.2828 - val_loss: 4.4986
#
# Epoch 00046: val_loss improved from 4.52513 to 4.49859, saving model to ssd300_udd_epoch-46_loss-4.2828_val_loss-4.4986.h5
# Epoch 47/120
#
# Epoch 00047: LearningRateScheduler reducing learning rate to 0.0003.
# 1000/1000 [==============================] - 666s 666ms/step - loss: 4.2696 - val_loss: 4.4647
#
# Epoch 00047: val_loss improved from 4.49859 to 4.46466, saving model to ssd300_udd_epoch-47_loss-4.2696_val_loss-4.4647.h5
# Epoch 48/120
#
# Epoch 00048: LearningRateScheduler reducing learning rate to 0.0003.
# 1000/1000 [==============================] - 674s 674ms/step - loss: 4.2356 - val_loss: 4.4628
#
# Epoch 00048: val_loss improved from 4.46466 to 4.46277, saving model to ssd300_udd_epoch-48_loss-4.2356_val_loss-4.4628.h5
# Epoch 49/120
#
# Epoch 00049: LearningRateScheduler reducing learning rate to 0.0003.
# 1000/1000 [==============================] - 666s 666ms/step - loss: 4.2282 - val_loss: 4.4492
#
# Epoch 00049: val_loss improved from 4.46277 to 4.44917, saving model to ssd300_udd_epoch-49_loss-4.2282_val_loss-4.4492.h5
# Epoch 50/120
#
# Epoch 00050: LearningRateScheduler reducing learning rate to 0.0003.
# 1000/1000 [==============================] - 667s 667ms/step - loss: 4.2083 - val_loss: 4.4551
#
# Epoch 00050: val_loss did not improve from 4.44917
# Epoch 51/120
#
# Epoch 00051: LearningRateScheduler reducing learning rate to 0.0003.
# 1000/1000 [==============================] - 666s 666ms/step - loss: 4.1923 - val_loss: 4.4231
#
# Epoch 00051: val_loss improved from 4.44917 to 4.42309, saving model to ssd300_udd_epoch-51_loss-4.1923_val_loss-4.4231.h5
# Epoch 52/120
#
# Epoch 00052: LearningRateScheduler reducing learning rate to 0.0003.
# 1000/1000 [==============================] - 666s 666ms/step - loss: 4.1654 - val_loss: 4.4106
#
# Epoch 00052: val_loss improved from 4.42309 to 4.41058, saving model to ssd300_udd_epoch-52_loss-4.1654_val_loss-4.4106.h5
# Epoch 53/120
#
# Epoch 00053: LearningRateScheduler reducing learning rate to 0.0003.
# 1000/1000 [==============================] - 666s 666ms/step - loss: 4.1565 - val_loss: 4.4297
#
# Epoch 00053: val_loss did not improve from 4.41058
# Epoch 54/120
#
# Epoch 00054: LearningRateScheduler reducing learning rate to 0.0003.
# 1000/1000 [==============================] - 667s 667ms/step - loss: 4.1389 - val_loss: 4.3883
#
# Epoch 00054: val_loss improved from 4.41058 to 4.38832, saving model to ssd300_udd_epoch-54_loss-4.1389_val_loss-4.3883.h5
# Epoch 55/120
#
# Epoch 00055: LearningRateScheduler reducing learning rate to 0.0003.
# 1000/1000 [==============================] - 667s 667ms/step - loss: 4.1155 - val_loss: 4.3527
#
# Epoch 00055: val_loss improved from 4.38832 to 4.35272, saving model to ssd300_udd_epoch-55_loss-4.1155_val_loss-4.3527.h5
# Epoch 56/120
#
# Epoch 00056: LearningRateScheduler reducing learning rate to 0.0003.
# 1000/1000 [==============================] - 666s 666ms/step - loss: 4.1066 - val_loss: 4.3464
#
# Epoch 00056: val_loss improved from 4.35272 to 4.34635, saving model to ssd300_udd_epoch-56_loss-4.1066_val_loss-4.3464.h5
# Epoch 57/120
#
# Epoch 00057: LearningRateScheduler reducing learning rate to 0.0003.
# 1000/1000 [==============================] - 667s 667ms/step - loss: 4.0843 - val_loss: 4.3462
#
# Epoch 00057: val_loss improved from 4.34635 to 4.34625, saving model to ssd300_udd_epoch-57_loss-4.0843_val_loss-4.3462.h5
# Epoch 58/120
#
# Epoch 00058: LearningRateScheduler reducing learning rate to 0.0003.
# 1000/1000 [==============================] - 667s 667ms/step - loss: 4.0770 - val_loss: 4.3531
#
# Epoch 00058: val_loss did not improve from 4.34625
# Epoch 59/120
#
# Epoch 00059: LearningRateScheduler reducing learning rate to 0.0003.
# 1000/1000 [==============================] - 667s 667ms/step - loss: 4.0628 - val_loss: 4.3209
#
# Epoch 00059: val_loss improved from 4.34625 to 4.32094, saving model to ssd300_udd_epoch-59_loss-4.0628_val_loss-4.3209.h5
# Epoch 60/120
#
# Epoch 00060: LearningRateScheduler reducing learning rate to 0.0003.
# 1000/1000 [==============================] - 666s 666ms/step - loss: 4.0419 - val_loss: 4.2976
#
# Epoch 00060: val_loss improved from 4.32094 to 4.29765, saving model to ssd300_udd_epoch-60_loss-4.0419_val_loss-4.2976.h5
# Epoch 61/120
#
# Epoch 00061: LearningRateScheduler reducing learning rate to 0.0003.
# 1000/1000 [==============================] - 666s 666ms/step - loss: 4.0192 - val_loss: 4.2826
#
# Epoch 00061: val_loss improved from 4.29765 to 4.28258, saving model to ssd300_udd_epoch-61_loss-4.0192_val_loss-4.2826.h5
# Epoch 62/120
#
# Epoch 00062: LearningRateScheduler reducing learning rate to 0.0003.
# 1000/1000 [==============================] - 667s 667ms/step - loss: 4.0076 - val_loss: 4.2700
#
# Epoch 00062: val_loss improved from 4.28258 to 4.27000, saving model to ssd300_udd_epoch-62_loss-4.0076_val_loss-4.2700.h5
# Epoch 63/120
#
# Epoch 00063: LearningRateScheduler reducing learning rate to 0.0003.
# 1000/1000 [==============================] - 667s 667ms/step - loss: 3.9928 - val_loss: 4.2811
#
# Epoch 00063: val_loss did not improve from 4.27000
# Epoch 64/120
#
# Epoch 00064: LearningRateScheduler reducing learning rate to 0.0003.
# 1000/1000 [==============================] - 667s 667ms/step - loss: 3.9707 - val_loss: 4.2517
#
# Epoch 00064: val_loss improved from 4.27000 to 4.25168, saving model to ssd300_udd_epoch-64_loss-3.9707_val_loss-4.2517.h5
# Epoch 65/120
#
# Epoch 00065: LearningRateScheduler reducing learning rate to 0.0003.
# 1000/1000 [==============================] - 666s 666ms/step - loss: 3.9606 - val_loss: 4.2325
#
# Epoch 00065: val_loss improved from 4.25168 to 4.23245, saving model to ssd300_udd_epoch-65_loss-3.9606_val_loss-4.2325.h5
# Epoch 66/120
#
# Epoch 00066: LearningRateScheduler reducing learning rate to 0.0003.
# 1000/1000 [==============================] - 667s 667ms/step - loss: 3.9452 - val_loss: 4.2329
#
# Epoch 00066: val_loss did not improve from 4.23245
# Epoch 67/120
#
# Epoch 00067: LearningRateScheduler reducing learning rate to 0.0003.
# 1000/1000 [==============================] - 667s 667ms/step - loss: 3.9330 - val_loss: 4.2231
#
# Epoch 00067: val_loss improved from 4.23245 to 4.22315, saving model to ssd300_udd_epoch-67_loss-3.9330_val_loss-4.2231.h5
# Epoch 68/120
#
# Epoch 00068: LearningRateScheduler reducing learning rate to 0.0003.
# 1000/1000 [==============================] - 667s 667ms/step - loss: 3.9084 - val_loss: 4.1911
#
# Epoch 00068: val_loss improved from 4.22315 to 4.19110, saving model to ssd300_udd_epoch-68_loss-3.9084_val_loss-4.1911.h5
# Epoch 69/120
#
# Epoch 00069: LearningRateScheduler reducing learning rate to 0.0003.
# 1000/1000 [==============================] - 667s 667ms/step - loss: 3.9037 - val_loss: 4.1842
#
# Epoch 00069: val_loss improved from 4.19110 to 4.18420, saving model to ssd300_udd_epoch-69_loss-3.9037_val_loss-4.1842.h5
# Epoch 70/120
#
# Epoch 00070: LearningRateScheduler reducing learning rate to 0.0003.
# 1000/1000 [==============================] - 667s 667ms/step - loss: 3.8834 - val_loss: 4.1773
#
# Epoch 00070: val_loss improved from 4.18420 to 4.17726, saving model to ssd300_udd_epoch-70_loss-3.8834_val_loss-4.1773.h5
# Epoch 71/120
#
# Epoch 00071: LearningRateScheduler reducing learning rate to 0.0003.
# 1000/1000 [==============================] - 667s 667ms/step - loss: 3.8755 - val_loss: 4.1788
#
# Epoch 00071: val_loss did not improve from 4.17726
# Epoch 72/120
#
# Epoch 00072: LearningRateScheduler reducing learning rate to 0.0003.
# 1000/1000 [==============================] - 667s 667ms/step - loss: 3.8520 - val_loss: 4.1457
#
# Epoch 00072: val_loss improved from 4.17726 to 4.14569, saving model to ssd300_udd_epoch-72_loss-3.8520_val_loss-4.1457.h5
# Epoch 73/120
#
# Epoch 00073: LearningRateScheduler reducing learning rate to 0.0003.
# 1000/1000 [==============================] - 667s 667ms/step - loss: 3.8462 - val_loss: 4.1689
#
# Epoch 00073: val_loss did not improve from 4.14569
# Epoch 74/120
#
# Epoch 00074: LearningRateScheduler reducing learning rate to 0.0003.
# 1000/1000 [==============================] - 666s 666ms/step - loss: 3.8274 - val_loss: 4.1219
#
# Epoch 00074: val_loss improved from 4.14569 to 4.12193, saving model to ssd300_udd_epoch-74_loss-3.8274_val_loss-4.1219.h5
# Epoch 75/120
#
# Epoch 00075: LearningRateScheduler reducing learning rate to 0.0003.
# 1000/1000 [==============================] - 667s 667ms/step - loss: 3.8144 - val_loss: 4.1351
#
# Epoch 00075: val_loss did not improve from 4.12193
# Epoch 76/120
#
# Epoch 00076: LearningRateScheduler reducing learning rate to 0.0003.
# 1000/1000 [==============================] - 666s 666ms/step - loss: 3.7959 - val_loss: 4.0980
#
# Epoch 00076: val_loss improved from 4.12193 to 4.09799, saving model to ssd300_udd_epoch-76_loss-3.7959_val_loss-4.0980.h5
# Epoch 77/120
#
# Epoch 00077: LearningRateScheduler reducing learning rate to 0.0003.
# 1000/1000 [==============================] - 666s 666ms/step - loss: 3.7818 - val_loss: 4.1152
#
# Epoch 00077: val_loss did not improve from 4.09799
# Epoch 78/120
#
# Epoch 00078: LearningRateScheduler reducing learning rate to 0.0003.
# 1000/1000 [==============================] - 666s 666ms/step - loss: 3.7761 - val_loss: 4.1228
#
# Epoch 00078: val_loss did not improve from 4.09799
# Epoch 79/120
#
# Epoch 00079: LearningRateScheduler reducing learning rate to 0.0003.
# 1000/1000 [==============================] - 677s 677ms/step - loss: 3.7599 - val_loss: 4.0712
#
# Epoch 00079: val_loss improved from 4.09799 to 4.07117, saving model to ssd300_udd_epoch-79_loss-3.7599_val_loss-4.0712.h5
# Epoch 80/120
#
# Epoch 00080: LearningRateScheduler reducing learning rate to 0.0003.
# 1000/1000 [==============================] - 667s 667ms/step - loss: 3.7435 - val_loss: 4.0835
#
# Epoch 00080: val_loss did not improve from 4.07117
# Epoch 81/120
#
# Epoch 00081: LearningRateScheduler reducing learning rate to 0.0001.
# 1000/1000 [==============================] - 666s 666ms/step - loss: 3.6972 - val_loss: 4.0532
#
# Epoch 00081: val_loss improved from 4.07117 to 4.05323, saving model to ssd300_udd_epoch-81_loss-3.6972_val_loss-4.0532.h5
# Epoch 82/120
#
# Epoch 00082: LearningRateScheduler reducing learning rate to 0.0001.
# 1000/1000 [==============================] - 666s 666ms/step - loss: 3.6848 - val_loss: 4.0329
#
# Epoch 00082: val_loss improved from 4.05323 to 4.03293, saving model to ssd300_udd_epoch-82_loss-3.6848_val_loss-4.0329.h5
# Epoch 83/120
#
# Epoch 00083: LearningRateScheduler reducing learning rate to 0.0001.
# 1000/1000 [==============================] - 666s 666ms/step - loss: 3.6751 - val_loss: 4.0281
#
# Epoch 00083: val_loss improved from 4.03293 to 4.02815, saving model to ssd300_udd_epoch-83_loss-3.6751_val_loss-4.0281.h5
# Epoch 84/120
#
# Epoch 00084: LearningRateScheduler reducing learning rate to 0.0001.
# 1000/1000 [==============================] - 667s 667ms/step - loss: 3.6778 - val_loss: 4.0283
#
# Epoch 00084: val_loss did not improve from 4.02815
# Epoch 85/120
#
# Epoch 00085: LearningRateScheduler reducing learning rate to 0.0001.
# 1000/1000 [==============================] - 666s 666ms/step - loss: 3.6655 - val_loss: 4.0204
#
# Epoch 00085: val_loss improved from 4.02815 to 4.02042, saving model to ssd300_udd_epoch-85_loss-3.6655_val_loss-4.0204.h5
# Epoch 86/120
#
# Epoch 00086: LearningRateScheduler reducing learning rate to 0.0001.
# 1000/1000 [==============================] - 667s 667ms/step - loss: 3.6730 - val_loss: 4.0211
#
# Epoch 00086: val_loss did not improve from 4.02042
# Epoch 87/120
#
# Epoch 00087: LearningRateScheduler reducing learning rate to 0.0001.
# 1000/1000 [==============================] - 667s 667ms/step - loss: 3.6592 - val_loss: 4.0080
#
# Epoch 00087: val_loss improved from 4.02042 to 4.00803, saving model to ssd300_udd_epoch-87_loss-3.6592_val_loss-4.0080.h5
# Epoch 88/120
#
# Epoch 00088: LearningRateScheduler reducing learning rate to 0.0001.
# 1000/1000 [==============================] - 667s 667ms/step - loss: 3.6640 - val_loss: 4.0089
#
# Epoch 00088: val_loss did not improve from 4.00803
# Epoch 89/120
#
# Epoch 00089: LearningRateScheduler reducing learning rate to 0.0001.
# 1000/1000 [==============================] - 666s 666ms/step - loss: 3.6442 - val_loss: 4.0129
#
# Epoch 00089: val_loss did not improve from 4.00803
# Epoch 90/120
#
# Epoch 00090: LearningRateScheduler reducing learning rate to 0.0001.
# 1000/1000 [==============================] - 666s 666ms/step - loss: 3.6503 - val_loss: 4.0086
#
# Epoch 00090: val_loss did not improve from 4.00803
# Epoch 91/120
#
# Epoch 00091: LearningRateScheduler reducing learning rate to 0.0001.
# 1000/1000 [==============================] - 666s 666ms/step - loss: 3.6436 - val_loss: 4.0095
#
# Epoch 00091: val_loss did not improve from 4.00803
# Epoch 92/120
#
# Epoch 00092: LearningRateScheduler reducing learning rate to 0.0001.
# 1000/1000 [==============================] - 679s 679ms/step - loss: 3.6422 - val_loss: 4.0106
#
# Epoch 00092: val_loss did not improve from 4.00803
# Epoch 93/120
#
# Epoch 00093: LearningRateScheduler reducing learning rate to 0.0001.
# 1000/1000 [==============================] - 666s 666ms/step - loss: 3.6271 - val_loss: 4.0053
#
# Epoch 00093: val_loss improved from 4.00803 to 4.00531, saving model to ssd300_udd_epoch-93_loss-3.6271_val_loss-4.0053.h5
# Epoch 94/120
#
# Epoch 00094: LearningRateScheduler reducing learning rate to 0.0001.
# 1000/1000 [==============================] - 679s 679ms/step - loss: 3.6346 - val_loss: 3.9775
#
# Epoch 00094: val_loss improved from 4.00531 to 3.97753, saving model to ssd300_udd_epoch-94_loss-3.6346_val_loss-3.9775.h5
# Epoch 95/120
#
# Epoch 00095: LearningRateScheduler reducing learning rate to 0.0001.
# 1000/1000 [==============================] - 667s 667ms/step - loss: 3.6216 - val_loss: 3.9967
#
# Epoch 00095: val_loss did not improve from 3.97753
# Epoch 96/120
#
# Epoch 00096: LearningRateScheduler reducing learning rate to 0.0001.
# 1000/1000 [==============================] - 679s 679ms/step - loss: 3.6236 - val_loss: 4.0064
#
# Epoch 00096: val_loss did not improve from 3.97753
# Epoch 97/120
#
# Epoch 00097: LearningRateScheduler reducing learning rate to 0.0001.
# 1000/1000 [==============================] - 666s 666ms/step - loss: 3.6112 - val_loss: 3.9808
#
# Epoch 00097: val_loss did not improve from 3.97753
# Epoch 98/120
#
# Epoch 00098: LearningRateScheduler reducing learning rate to 0.0001.
# 1000/1000 [==============================] - 666s 666ms/step - loss: 3.6184 - val_loss: 3.9749
#
# Epoch 00098: val_loss improved from 3.97753 to 3.97486, saving model to ssd300_udd_epoch-98_loss-3.6184_val_loss-3.9749.h5
# Epoch 99/120
#
# Epoch 00099: LearningRateScheduler reducing learning rate to 0.0001.
# 1000/1000 [==============================] - 666s 666ms/step - loss: 3.6085 - val_loss: 3.9739
#
# Epoch 00099: val_loss improved from 3.97486 to 3.97390, saving model to ssd300_udd_epoch-99_loss-3.6085_val_loss-3.9739.h5
# Epoch 100/120
#
# Epoch 00100: LearningRateScheduler reducing learning rate to 0.0001.
# 1000/1000 [==============================] - 666s 666ms/step - loss: 3.6041 - val_loss: 3.9863
#
# Epoch 00100: val_loss did not improve from 3.97390
# Epoch 101/120
#
# Epoch 00101: LearningRateScheduler reducing learning rate to 1e-05.
# 1000/1000 [==============================] - 667s 667ms/step - loss: 3.5862 - val_loss: 3.9631
#
# Epoch 00101: val_loss improved from 3.97390 to 3.96311, saving model to ssd300_udd_epoch-101_loss-3.5862_val_loss-3.9631.h5
# Epoch 102/120
#
# Epoch 00102: LearningRateScheduler reducing learning rate to 1e-05.
# 1000/1000 [==============================] - 678s 678ms/step - loss: 3.5788 - val_loss: 3.9588
#
# Epoch 00102: val_loss improved from 3.96311 to 3.95877, saving model to ssd300_udd_epoch-102_loss-3.5788_val_loss-3.9588.h5
# Epoch 103/120
#
# Epoch 00103: LearningRateScheduler reducing learning rate to 1e-05.
# 1000/1000 [==============================] - 668s 668ms/step - loss: 3.5821 - val_loss: 3.9565
#
# Epoch 00103: val_loss improved from 3.95877 to 3.95649, saving model to ssd300_udd_epoch-103_loss-3.5821_val_loss-3.9565.h5
# Epoch 104/120
#
# Epoch 00104: LearningRateScheduler reducing learning rate to 1e-05.
# 1000/1000 [==============================] - 668s 668ms/step - loss: 3.5701 - val_loss: 3.9558
#
# Epoch 00104: val_loss improved from 3.95649 to 3.95583, saving model to ssd300_udd_epoch-104_loss-3.5701_val_loss-3.9558.h5
# Epoch 105/120
#
# Epoch 00105: LearningRateScheduler reducing learning rate to 1e-05.
# 1000/1000 [==============================] - 668s 668ms/step - loss: 3.5745 - val_loss: 3.9601
#
# Epoch 00105: val_loss did not improve from 3.95583
# Epoch 106/120
#
# Epoch 00106: LearningRateScheduler reducing learning rate to 1e-05.
# 1000/1000 [==============================] - 667s 667ms/step - loss: 3.5807 - val_loss: 3.9562
#
# Epoch 00106: val_loss did not improve from 3.95583
# Epoch 107/120
#
# Epoch 00107: LearningRateScheduler reducing learning rate to 1e-05.
# 1000/1000 [==============================] - 667s 667ms/step - loss: 3.5742 - val_loss: 3.9569
#
# Epoch 00107: val_loss did not improve from 3.95583
# Epoch 108/120
#
# Epoch 00108: LearningRateScheduler reducing learning rate to 1e-05.
# 1000/1000 [==============================] - 667s 667ms/step - loss: 3.5758 - val_loss: 3.9556
#
# Epoch 00108: val_loss improved from 3.95583 to 3.95560, saving model to ssd300_udd_epoch-108_loss-3.5758_val_loss-3.9556.h5
# Epoch 109/120
#
# Epoch 00109: LearningRateScheduler reducing learning rate to 1e-05.
# 1000/1000 [==============================] - 667s 667ms/step - loss: 3.5790 - val_loss: 3.9579
#
# Epoch 00109: val_loss did not improve from 3.95560
# Epoch 110/120
#
# Epoch 00110: LearningRateScheduler reducing learning rate to 1e-05.
# 1000/1000 [==============================] - 667s 667ms/step - loss: 3.5755 - val_loss: 3.9582
#
# Epoch 00110: val_loss did not improve from 3.95560
# Epoch 111/120
#
# Epoch 00111: LearningRateScheduler reducing learning rate to 1e-05.
# 1000/1000 [==============================] - 668s 668ms/step - loss: 3.5741 - val_loss: 3.9595
#
# Epoch 00111: val_loss did not improve from 3.95560
# Epoch 112/120
#
# Epoch 00112: LearningRateScheduler reducing learning rate to 1e-05.
# 1000/1000 [==============================] - 681s 681ms/step - loss: 3.5727 - val_loss: 3.9610
#
# Epoch 00112: val_loss did not improve from 3.95560
# Epoch 113/120
#
# Epoch 00113: LearningRateScheduler reducing learning rate to 1e-05.
# 1000/1000 [==============================] - 667s 667ms/step - loss: 3.5704 - val_loss: 3.9575
#
# Epoch 00113: val_loss did not improve from 3.95560
# Epoch 114/120
#
# Epoch 00114: LearningRateScheduler reducing learning rate to 1e-05.
# 1000/1000 [==============================] - 668s 668ms/step - loss: 3.5693 - val_loss: 3.9617
#
# Epoch 00114: val_loss did not improve from 3.95560
# Epoch 115/120
#
# Epoch 00115: LearningRateScheduler reducing learning rate to 1e-05.
# 1000/1000 [==============================] - 668s 668ms/step - loss: 3.5720 - val_loss: 3.9572
#
# Epoch 00115: val_loss did not improve from 3.95560
# Epoch 116/120
#
# Epoch 00116: LearningRateScheduler reducing learning rate to 1e-05.
# 1000/1000 [==============================] - 667s 667ms/step - loss: 3.5669 - val_loss: 3.9588
#
# Epoch 00116: val_loss did not improve from 3.95560
# Epoch 117/120
#
# Epoch 00117: LearningRateScheduler reducing learning rate to 1e-05.
# 1000/1000 [==============================] - 668s 668ms/step - loss: 3.5770 - val_loss: 3.9583
#
# Epoch 00117: val_loss did not improve from 3.95560
# Epoch 118/120
#
# Epoch 00118: LearningRateScheduler reducing learning rate to 1e-05.
# 1000/1000 [==============================] - 669s 669ms/step - loss: 3.5612 - val_loss: 3.9578
#
# Epoch 00118: val_loss did not improve from 3.95560
# Epoch 119/120
#
# Epoch 00119: LearningRateScheduler reducing learning rate to 1e-05.
# 1000/1000 [==============================] - 669s 669ms/step - loss: 3.5706 - val_loss: 3.9577
#
# Epoch 00119: val_loss did not improve from 3.95560
# Epoch 120/120
#
# Epoch 00120: LearningRateScheduler reducing learning rate to 1e-05.
# 1000/1000 [==============================] - 670s 670ms/step - loss: 3.5763 - val_loss: 3.9551
#
# Epoch 00120: val_loss improved from 3.95560 to 3.95505, saving model to ssd300_udd_epoch-120_loss-3.5763_val_loss-3.9551.h5

# %% [markdown]
# ## 6. Make predictions
#
# Now let's make some predictions on the validation dataset with the trained model. For convenience we'll use the validation generator that we've already set up above. Feel free to change the batch size.
#
# You can set the `shuffle` option to `False` if you would like to check the model's progress on the same image(s) over the course of the training.

# %%
# 1: Set the generator for the predictions.

predict_generator = val_dataset.generate(batch_size=1,
                                         shuffle=True,
                                         transformations=[convert_to_3_channels,
                                                          resize],
                                         label_encoder=None,
                                         returns={'processed_images',
                                                  'filenames',
                                                  'inverse_transform',
                                                  'original_images',
                                                  'original_labels'},
                                         keep_images_without_gt=False)

# %%
# 2: Generate samples.

batch_images, batch_filenames, batch_inverse_transforms, batch_original_images, batch_original_labels = next(predict_generator)

i = 0 # Which batch item to look at

print("Image:", batch_filenames[i])
print()
print("Ground truth boxes:\n")
print(np.array(batch_original_labels[i]))
# Out:
# Image: /home/jerry/Datasets/udacity_driving_datasets/JPEGImages/1478899665414968312.jpg
#
# Ground truth boxes:
#
# [[  1  79 142 138 193]
#  [  1 258 142 286 189]
#  [  1 274 140 321 218]
#  [  1 318 130 478 291]]

# %%
# 3: Make predictions.

y_pred = model.predict(batch_images)

# %% [markdown]
# Now let's decode the raw predictions in `y_pred`.
#
# Had we created the model in 'inference' or 'inference_fast' mode, then the model's final layer would be a `DecodeDetections` layer and `y_pred` would already contain the decoded predictions, but since we created the model in 'training' mode, the model outputs raw predictions that still need to be decoded and filtered. This is what the `decode_detections()` function is for. It does exactly what the `DecodeDetections` layer would do, but using Numpy instead of TensorFlow (i.e. on the CPU instead of the GPU).
#
# `decode_detections()` with default argument values follows the procedure of the original SSD implementation: First, a very low confidence threshold of 0.01 is applied to filter out the majority of the predicted boxes, then greedy non-maximum suppression is performed per class with an intersection-over-union threshold of 0.45, and out of what is left after that, the top 200 highest confidence boxes are returned. Those settings are for precision-recall scoring purposes though. In order to get some usable final predictions, we'll set the confidence threshold much higher, e.g. to 0.5, since we're only interested in the very confident predictions.

# %%
# 4: Decode the raw predictions in `y_pred`.

y_pred_decoded = decode_detections(y_pred,
                                   confidence_thresh=0.5,
                                   iou_threshold=0.4,
                                   top_k=200,
                                   normalize_coords=normalize_coords,
                                   img_height=img_height,
                                   img_width=img_width)

# %% [markdown]
# We made the predictions on the resized images, but we'd like to visualize the outcome on the original input images, so we'll convert the coordinates accordingly. Don't worry about that opaque `apply_inverse_transforms()` function below, in this simple case it just aplies `(* original_image_size / resized_image_size)` to the box coordinates.

# %%
# 5: Convert the predictions for the original image.

y_pred_decoded_inv = apply_inverse_transforms(y_pred_decoded, batch_inverse_transforms)

np.set_printoptions(precision=2, suppress=True, linewidth=90)
print("Predicted boxes:\n")
print('   class   conf xmin   ymin   xmax   ymax')
print(y_pred_decoded_inv[i])
# Out:
# Predicted boxes:
#
#    class   conf xmin   ymin   xmax   ymax
# [[  1.     0.99  77.   144.   144.   191.  ]
#  [  1.     0.98 277.   134.   361.   217.  ]
#  [  1.     0.98 351.   172.   509.   312.  ]
#  [  1.     0.97 365.    99.   480.   264.  ]
#  [  1.     0.88 256.   139.   302.   189.  ]
#  [  1.     0.84   0.   139.    85.   222.  ]
#  [  1.     0.81 220.   146.   243.   163.  ]
#  [  1.     0.66 133.   147.   153.   165.  ]
#  [  1.     0.6  181.   149.   195.   161.  ]]

# %% [markdown]
# Finally, let's draw the predicted boxes onto the image. Each predicted box says its confidence next to the category name. The ground truth boxes are also drawn onto the image in green for comparison.

# %%
# 5: Draw the predicted boxes onto the image

# Set the colors for the bounding boxes
colors = plt.cm.hsv(np.linspace(0, 1, n_classes+1)).tolist()
classes = ['background',
           'car', 'truck', 'pedestrian', 'bicyclist', 'light']

plt.figure(figsize=(20,12))
plt.imshow(batch_original_images[i])

current_axis = plt.gca()

for box in batch_original_labels[i]:
    xmin = box[1]
    ymin = box[2]
    xmax = box[3]
    ymax = box[4]
    label = '{}'.format(classes[int(box[0])])
    current_axis.add_patch(plt.Rectangle((xmin, ymin), xmax-xmin, ymax-ymin, color='green', fill=False, linewidth=2))  
    current_axis.text(xmin, ymin, label, size='x-large', color='white', bbox={'facecolor':'green', 'alpha':1.0})

for box in y_pred_decoded_inv[i]:
    xmin = box[2]
    ymin = box[3]
    xmax = box[4]
    ymax = box[5]
    color = colors[int(box[0])]
    label = '{}: {:.2f}'.format(classes[int(box[0])], box[1])
    current_axis.add_patch(plt.Rectangle((xmin, ymin), xmax-xmin, ymax-ymin, color=color, fill=False, linewidth=2))  
    current_axis.text(xmin, ymin, label, size='x-large', color='white', bbox={'facecolor':color, 'alpha':1.0})
